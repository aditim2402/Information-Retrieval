# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import random
import numpy as np

# Function to extract page ID from the filename
def get_page_id(file_name):
    match = re.search(r'page(\d+)', file_name)
    if match:
        return int(match.group(1))
    else:
        return None

# Function to extract page name from the filename
def get_page_name(file_name):
    # Extract page name from the filename by removing the file extension
    return os.path.splitext(file_name)[0]

# Function to preprocess the document content
def preprocess_document(document_content):
    # Tokenize the content by splitting on spaces (you can use more advanced tokenization)
    words = document_content.split()

    # Remove stop words, special characters, and sentence delimiters
    stop_words = set(["the", "and", "is", "in", "it", "an", "to", "of", "as", "by"])
    words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

    # Calculate total weight (word count) and total count word
    total_weight = len(words)
    total_count_word = len(set(words))

    return total_weight, total_count_word, words

# Function to perform document indexing
def document_indexing(dataset_path):
    pages_information = {}
    words_information = {}

    for root, _, files in os.walk(dataset_path):
        for file_name in files:
            if file_name.endswith(".txt"):
                with open(os.path.join(root, file_name), 'r', encoding='utf-8') as file:
                    document_content = file.read()
                    total_weight, total_count_word, words = preprocess_document(document_content)

                    page_id = get_page_id(file_name)
                    page_name = get_page_name(file_name)

                    # Store page information
                    pages_information[page_id] = {
                        "page_name": page_name,
                        "total_weight": total_weight,
                        "total_count_word": total_count_word,
                    }

                    # Update words information
                    for word in words:
                        if word not in words_information:
                            words_information[word] = {"pages_list": [page_id]}
                        else:
                            words_information[word]["pages_list"].append(page_id)

    return pages_information, words_information

# Function to perform query search
def query_search(user_query, words_information):
    query_words = user_query.lower().split()
    id_list = []

    for word in query_words:
        if word in words_information:
            id_list.extend(words_information[word]["pages_list"])

    return list(set(id_list))  # Remove duplicates

# Function to perform the modified GA procedure
def modified_genetic_algorithm(population_size, num_iterations):
    # Replace this with your actual genetic algorithm logic
    # Here, we'll just generate random fitness values for demonstration
    fitness_values = [random.random() for _ in range(population_size)]

    # Return the best fitness value after the specified number of iterations
    best_fitness = max(fitness_values)
    return best_fitness

# Example usage
if __name__ == "__main__":
    dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"

    # Algorithm 1: Document Indexing
    pages_information, words_information = document_indexing(dataset_path)

    # Algorithm 2: Query Search
    user_query = "Required"
    relevant_page_ids = query_search(user_query, words_information)

    # Algorithm 3: Modified Genetic Algorithm
    population_size = 50
    num_iterations = 15
    best_fitness = modified_genetic_algorithm(population_size, num_iterations)

    # Print results
    print("Pages Information:")
    for page_id, page_info in pages_information.items():
        print(f"Page ID: {page_id}, Page Name: {page_info['page_name']}, Total Weight: {page_info['total_weight']}, Total Count Word: {page_info['total_count_word']}")

    print("\nWords Information:")
    for word, word_info in words_information.items():
        print(f"Word: {word}, Pages List: {word_info['pages_list']}")

    print("\nRelevant Page IDs for Query:", relevant_page_ids)
    print("Best Fitness Value:", best_fitness)
# Out:
# Pages Information:
# Page ID: None, Page Name: http_^^www.cs.clemson.edu^~madhu^usa, Total Weight: 1085, Total Count Word: 649
#
# Words Information:
# Word: 14, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: jan, Pages List: [None, None, None, None, None, None, None]
# Word: 1997, Pages List: [None, None, None, None, None, None, None]
# Word: gmt, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 15, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None]
# Word: feb, Pages List: [None]
# Word: 1996, Pages List: [None, None, None]
# Word: 3082, Pages List: [None]
# Word: problem, Pages List: [None, None, None, None, None]
# Word: 1, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None]
# Word: part, Pages List: [None, None, None, None, None, None, None, None]
# Word: a, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: though, Pages List: [None, None]
# Word: not, Pages List: [None, None, None, None, None]
# Word: for, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None]
# Word: longer, Pages List: [None]
# Word: but, Pages List: [None, None, None, None, None, None, None]
# Word: was, Pages List: [None]
# Word: b, Pages List: [None, None]
# Word: grandparent, Pages List: [None]
# Word: parent, Pages List: [None, None, None, None, None, None]
# Word: x, Pages List: [None, None, None, None, None, None, None]
# Word: mother, Pages List: [None, None]
# Word: y, Pages List: [None, None, None]
# Word: if, Pages List: [None, None, None, None, None, None, None]
# Word: female, Pages List: [None]
# Word: sibling, Pages List: [None, None]
# Word: different, Pages List: [None]
# Word: person, Pages List: [None, None, None, None]
# Word: with, Pages List: [None, None, None, None, None, None, None]
# Word: same, Pages List: [None, None]
# Word: sister, Pages List: [None, None]
# Word: law, Pages List: [None, None]
# Word: either, Pages List: [None, None, None]
# Word: or, Pages List: [None, None, None, None, None, None, None]
# Word: wife, Pages List: [None, None]
# Word: c, Pages List: [None]
# Word: that, Pages List: [None, None, None]
# Word: this, Pages List: [None, None, None]
# Word: often, Pages List: [None]
# Word: go, Pages List: [None]
# Word: into, Pages List: [None]
# Word: infinite, Pages List: [None]
# Word: you, Pages List: [None, None, None]
# Word: ask, Pages List: [None, None, None]
# Word: query, Pages List: [None]
# Word: whose, Pages List: [None]
# Word: answer, Pages List: [None, None, None]
# Word: should, Pages List: [None]
# Word: be, Pages List: [None, None, None, None, None, None, None]
# Word: find, Pages List: [None, None]
# Word: spouse, Pages List: [None, None]
# Word: unmarried, Pages List: [None]
# Word: who, Pages List: [None]
# Word: will, Pages List: [None]
# Word: return, Pages List: [None, None]
# Word: infinitely, Pages List: [None]
# Word: many, Pages List: [None, None]
# Word: times, Pages List: [None]
# Word: on, Pages List: [None, None, None, None, None, None, None, None]
# Word: diana, Pages List: [None, None, None]
# Word: requesting, Pages List: [None, None]
# Word: another, Pages List: [None, None, None]
# Word: use, Pages List: [None]
# Word: auxiliary, Pages List: [None]
# Word: predicate, Pages List: [None]
# Word: state, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: fact, Pages List: [None]
# Word: once, Pages List: [None, None, None]
# Word: each, Pages List: [None, None, None]
# Word: then, Pages List: [None, None]
# Word: define, Pages List: [None]
# Word: terms, Pages List: [None]
# Word: 2, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: run, Pages List: [None]
# Word: backwards, Pages List: [None]
# Word: split, Pages List: [None]
# Word: last, Pages List: [None, None, None, None, None]
# Word: element, Pages List: [None, None, None]
# Word: from, Pages List: [None, None, None, None]
# Word: rest, Pages List: [None]
# Word: them, Pages List: [None]
# Word: connected, Pages List: [None, None]
# Word: other, Pages List: [None, None, None, None, None]
# Word: more, Pages List: [None, None, None]
# Word: straightforward, Pages List: [None]
# Word: take, Pages List: [None, None, None]
# Word: off, Pages List: [None, None]
# Word: all, Pages List: [None, None, None, None]
# Word: reconnect, Pages List: [None]
# Word: binds, Pages List: [None, None, None]
# Word: r, Pages List: [None, None]
# Word: rotates, Pages List: [None]
# Word: succeeds, Pages List: [None]
# Word: applies, Pages List: [None]
# Word: k, Pages List: [None, None, None]
# Word: rotations, Pages List: [None]
# Word: returning, Pages List: [None]
# Word: k1, Pages List: [None]
# Word: m, Pages List: [None, None, None, None]
# Word: rotation, Pages List: [None]
# Word: l, Pages List: [None, None]
# Word: keeps, Pages List: [None]
# Word: rotating, Pages List: [None]
# Word: backtrackings, Pages List: [None]
# Word: are, Pages List: [None, None, None, None, None, None]
# Word: 4, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: n, Pages List: [None, None]
# Word: n1, Pages List: [None]
# Word: e, Pages List: [None]
# Word: 522, Pages List: [None]
# Word: 08, Pages List: [None]
# Word: 2578, Pages List: [None]
# Word: atomic, Pages List: [None, None]
# Word: transaction, Pages List: [None, None, None, None, None, None, None]
# Word: like, Pages List: [None]
# Word: signing, Pages List: [None]
# Word: contract, Pages List: [None]
# Word: two, Pages List: [None, None]
# Word: they, Pages List: [None]
# Word: both, Pages List: [None, None, None]
# Word: fig, Pages List: [None, None, None, None, None, None, None]
# Word: withdraw, Pages List: [None]
# Word: my, Pages List: [None]
# Word: deposit, Pages List: [None]
# Word: your, Pages List: [None]
# Word: model, Pages List: [None]
# Word: independent, Pages List: [None]
# Word: which, Pages List: [None, None, None, None, None, None]
# Word: can, Pages List: [None, None, None, None, None]
# Word: fail, Pages List: [None]
# Word: at, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: random, Pages List: [None]
# Word: communication, Pages List: [None]
# Word: reliable, Pages List: [None]
# Word: timeout, Pages List: [None]
# Word: stable, Pages List: [None, None, None]
# Word: storage, Pages List: [None, None, None, None]
# Word: 3, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: types, Pages List: [None]
# Word: ram, Pages List: [None]
# Word: power, Pages List: [None]
# Word: machine, Pages List: [None]
# Word: crashes, Pages List: [None, None]
# Word: disk, Pages List: [None, None]
# Word: survives, Pages List: [None]
# Word: cpu, Pages List: [None]
# Word: failures, Pages List: [None, None]
# Word: lost, Pages List: [None]
# Word: head, Pages List: [None]
# Word: designed, Pages List: [None, None, None]
# Word: survive, Pages List: [None]
# Word: any, Pages List: [None, None]
# Word: primitive, Pages List: [None]
# Word: start, Pages List: [None]
# Word: terminate, Pages List: [None]
# Word: commit, Pages List: [None, None, None, None, None, None, None]
# Word: kill, Pages List: [None]
# Word: restore, Pages List: [None]
# Word: old, Pages List: [None, None, None]
# Word: value, Pages List: [None]
# Word: read, Pages List: [None]
# Word: write, Pages List: [None, None]
# Word: properties, Pages List: [None]
# Word: transactions, Pages List: [None, None, None, None]
# Word: indivisible, Pages List: [None]
# Word: outside, Pages List: [None]
# Word: maintain, Pages List: [None]
# Word: system, Pages List: [None, None, None, None]
# Word: invariants, Pages List: [None]
# Word: no, Pages List: [None, None, None]
# Word: interference, Pages List: [None]
# Word: concurrent, Pages List: [None, None, None]
# Word: committed, Pages List: [None, None]
# Word: changes, Pages List: [None, None]
# Word: permanent, Pages List: [None]
# Word: append, Pages List: [None]
# Word: file, Pages List: [None, None]
# Word: consistent, Pages List: [None, None]
# Word: conservation, Pages List: [None]
# Word: money, Pages List: [None]
# Word: isolated, Pages List: [None]
# Word: serializable, Pages List: [None]
# Word: serial, Pages List: [None]
# Word: serialized, Pages List: [None]
# Word: ok, Pages List: [None, None]
# Word: since, Pages List: [None]
# Word: values, Pages List: [None, None]
# Word: illegal, Pages List: [None]
# Word: nested, Pages List: [None]
# Word: may, Pages List: [None]
# Word: execute, Pages List: [None]
# Word: one, Pages List: [None, None]
# Word: subtransactions, Pages List: [None]
# Word: when, Pages List: [None, None, None]
# Word: subtransaction, Pages List: [None, None]
# Word: its, Pages List: [None, None]
# Word: results, Pages List: [None, None]
# Word: visible, Pages List: [None]
# Word: must, Pages List: [None]
# Word: implementation, Pages List: [None]
# Word: how, Pages List: [None, None, None]
# Word: undo, Pages List: [None]
# Word: intermediate, Pages List: [None]
# Word: updates, Pages List: [None]
# Word: private, Pages List: [None, None]
# Word: workspace, Pages List: [None, None]
# Word: give, Pages List: [None]
# Word: copy, Pages List: [None]
# Word: needed, Pages List: [None]
# Word: writeahead, Pages List: [None]
# Word: log, Pages List: [None, None, None, None]
# Word: intentions, Pages List: [None]
# Word: files, Pages List: [None, None]
# Word: actually, Pages List: [None]
# Word: modified, Pages List: [None]
# Word: place, Pages List: [None]
# Word: before, Pages List: [None, None]
# Word: record, Pages List: [None, None]
# Word: written, Pages List: [None, None]
# Word: new, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: after, Pages List: [None]
# Word: changed, Pages List: [None]
# Word: undone, Pages List: [None]
# Word: also, Pages List: [None, None, None]
# Word: used, Pages List: [None, None]
# Word: recovering, Pages List: [None]
# Word: protocol, Pages List: [None, None, None]
# Word: atomically, Pages List: [None]
# Word: why, Pages List: [None]
# Word: general, Pages List: [None]
# Word: paradox, Pages List: [None]
# Word: generals, Pages List: [None]
# Word: want, Pages List: [None]
# Word: agree, Pages List: [None, None]
# Word: time, Pages List: [None]
# Word: even, Pages List: [None]
# Word: some, Pages List: [None]
# Word: messengers, Pages List: [None]
# Word: do, Pages List: [None]
# Word: get, Pages List: [None]
# Word: impossibility, Pages List: [None]
# Word: assume, Pages List: [None]
# Word: exist, Pages List: [None]
# Word: shortest, Pages List: [None]
# Word: sequence, Pages List: [None]
# Word: msgs, Pages List: [None, None]
# Word: goal, Pages List: [None]
# Word: sites, Pages List: [None]
# Word: abort, Pages List: [None]
# Word: relax, Pages List: [None]
# Word: req, Pages List: [None]
# Word: number, Pages List: [None, None]
# Word: bounded, Pages List: [None]
# Word: fixed, Pages List: [None]
# Word: 337, Pages List: [None]
# Word: 18, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: dec, Pages List: [None, None]
# Word: 6459, Pages List: [None]
# Word: column, Pages List: [None]
# Word: heading, Pages List: [None]
# Word: means, Pages List: [None]
# Word: assignment, Pages List: [None]
# Word: worth, Pages List: [None]
# Word: total, Pages List: [None, None]
# Word: points, Pages List: [None, None]
# Word: extra, Pages List: [None, None]
# Word: hmwk1, Pages List: [None]
# Word: hmwk2, Pages List: [None]
# Word: hmwk3, Pages List: [None]
# Word: hmwk4, Pages List: [None]
# Word: mid, Pages List: [None]
# Word: hmwk5, Pages List: [None]
# Word: hmwk6, Pages List: [None]
# Word: hmwk7, Pages List: [None]
# Word: hmwk8, Pages List: [None]
# Word: hmwk9, Pages List: [None]
# Word: final, Pages List: [None]
# Word: 7, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 39, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 51, Pages List: [None, None]
# Word: 5, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 8, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 21, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 6, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 27, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 9, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 11, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 33, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 13, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 45, Pages List: [None, None, None, None, None, None, None]
# Word: 10, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 12, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 36, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 24, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 30, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 42, Pages List: [None, None, None, None, None, None, None, None, None, None]
# Word: 0, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 48, Pages List: [None, None]
# Word: 47, Pages List: [None, None]
# Word: 1396, Pages List: [None]
# Word: sep, Pages List: [None]
# Word: name, Pages List: [None, None]
# Word: username, Pages List: [None]
# Word: known, Pages List: [None]
# Word: address, Pages List: [None]
# Word: blau, Pages List: [None]
# Word: seth, Pages List: [None]
# Word: d, Pages List: [None, None]
# Word: sdb5200, Pages List: [None]
# Word: carr, Pages List: [None]
# Word: richard, Pages List: [None]
# Word: rrc8372, Pages List: [None]
# Word: diament, Pages List: [None]
# Word: judah, Pages List: [None]
# Word: michael, Pages List: [None, None]
# Word: jmd205, Pages List: [None]
# Word: elkin, Pages List: [None]
# Word: vadim, Pages List: [None]
# Word: ve201, Pages List: [None]
# Word: fuh, Pages List: [None]
# Word: paul, Pages List: [None]
# Word: pqf3581, Pages List: [None]
# Word: hanna, Pages List: [None]
# Word: adel, Pages List: [None]
# Word: ah1, Pages List: [None]
# Word: hertzmann, Pages List: [None]
# Word: aaron, Pages List: [None]
# Word: phillip, Pages List: [None]
# Word: aph201, Pages List: [None]
# Word: huggins, Pages List: [None]
# Word: patrick, Pages List: [None]
# Word: s, Pages List: [None]
# Word: psh9057, Pages List: [None]
# Word: jawalekar, Pages List: [None]
# Word: raju, Pages List: [None]
# Word: v, Pages List: [None, None, None, None, None]
# Word: rvj1, Pages List: [None]
# Word: jermyn, Pages List: [None]
# Word: ian, Pages List: [None]
# Word: hyla, Pages List: [None]
# Word: ihj200, Pages List: [None]
# Word: kim, Pages List: [None]
# Word: jae, Pages List: [None]
# Word: hwan, Pages List: [None]
# Word: jhk5364, Pages List: [None]
# Word: llaurado, Pages List: [None]
# Word: ramon, Pages List: [None]
# Word: rql6719, Pages List: [None]
# Word: newman, Pages List: [None]
# Word: joshua, Pages List: [None]
# Word: amiel, Pages List: [None]
# Word: jqn0794, Pages List: [None]
# Word: pao, Pages List: [None]
# Word: hkp1, Pages List: [None]
# Word: raskin, Pages List: [None]
# Word: gabriel, Pages List: [None]
# Word: carl, Pages List: [None]
# Word: gcr3340, Pages List: [None]
# Word: sceniak, Pages List: [None]
# Word: p, Pages List: [None, None]
# Word: mps1707, Pages List: [None]
# Word: singer, Pages List: [None]
# Word: eric, Pages List: [None]
# Word: lee, Pages List: [None]
# Word: els3339, Pages List: [None]
# Word: wu, Pages List: [None]
# Word: xiangyang, Pages List: [None]
# Word: xqw5048, Pages List: [None]
# Word: 09, Pages List: [None]
# Word: 1994, Pages List: [None]
# Word: 2709, Pages List: [None]
# Word: user, Pages List: [None]
# Word: commands, Pages List: [None]
# Word: arthur, Pages List: [None, None, None, None, None, None]
# Word: intelligence, Pages List: [None]
# Word: language, Pages List: [None]
# Word: process, Pages List: [None, None, None, None]
# Word: tactile, Pages List: [None]
# Word: audible, Pages List: [None]
# Word: express, Pages List: [None]
# Word: purpose, Pages List: [None]
# Word: interacting, Pages List: [None]
# Word: synopsis, Pages List: [None, None]
# Word: play, Pages List: [None, None]
# Word: availability, Pages List: [None]
# Word: version, Pages List: [None]
# Word: command, Pages List: [None]
# Word: available, Pages List: [None]
# Word: tem, Pages List: [None]
# Word: software, Pages List: [None]
# Word: installation, Pages List: [None]
# Word: refer, Pages List: [None]
# Word: installing, Pages List: [None]
# Word: sunos, Pages List: [None]
# Word: information, Pages List: [None]
# Word: install, Pages List: [None]
# Word: invoke, Pages List: [None]
# Word: description, Pages List: [None]
# Word: invoked, Pages List: [None]
# Word: four, Pages List: [None]
# Word: major, Pages List: [None]
# Word: involves, Pages List: [None]
# Word: output, Pages List: [None]
# Word: depends, Pages List: [None]
# Word: complicated, Pages List: [None]
# Word: way, Pages List: [None, None]
# Word: sensory, Pages List: [None]
# Word: options, Pages List: [None]
# Word: option, Pages List: [None, None, None, None]
# Word: allows, Pages List: [None]
# Word: dormant, Pages List: [None]
# Word: period, Pages List: [None]
# Word: temporarily, Pages List: [None]
# Word: suspends, Pages List: [None]
# Word: processes, Pages List: [None]
# Word: food, Pages List: [None]
# Word: specify, Pages List: [None]
# Word: calories, Pages List: [None]
# Word: color, Pages List: [None]
# Word: q, Pages List: [None]
# Word: operating, Pages List: [None]
# Word: wide, Pages List: [None]
# Word: ranging, Pages List: [None]
# Word: field, Pages List: [None]
# Word: examples, Pages List: [None]
# Word: include, Pages List: [None]
# Word: early, Pages List: [None]
# Word: morning, Pages List: [None]
# Word: programming, Pages List: [None]
# Word: sessions, Pages List: [None]
# Word: porch, Pages List: [None]
# Word: portable, Pages List: [None]
# Word: late, Pages List: [None]
# Word: night, Pages List: [None]
# Word: doodling, Pages List: [None]
# Word: unreadable, Pages List: [None]
# Word: mix, Pages List: [None]
# Word: print, Pages List: [None]
# Word: script, Pages List: [None]
# Word: ubiquitous, Pages List: [None]
# Word: spiral, Pages List: [None]
# Word: bound, Pages List: [None]
# Word: college, Pages List: [None, None, None, None, None, None, None]
# Word: recently, Pages List: [None]
# Word: installed, Pages List: [None]
# Word: significantly, Pages List: [None]
# Word: upgraded, Pages List: [None]
# Word: now, Pages List: [None]
# Word: forevermore, Pages List: [None]
# Word: includes, Pages List: [None]
# Word: pipe, Pages List: [None]
# Word: result, Pages List: [None]
# Word: successful, Pages List: [None]
# Word: execution, Pages List: [None]
# Word: happiness, Pages List: [None]
# Word: bugs, Pages List: [None]
# Word: initiated, Pages List: [None]
# Word: given, Pages List: [None]
# Word: there, Pages List: [None]
# Word: easy, Pages List: [None]
# Word: transfer, Pages List: [None]
# Word: operations, Pages List: [None]
# Word: especially, Pages List: [None]
# Word: true, Pages List: [None]
# Word: reading, Pages List: [None]
# Word: considered, Pages List: [None]
# Word: work, Pages List: [None]
# Word: unusual, Pages List: [None]
# Word: propensity, Pages List: [None]
# Word: think, Pages List: [None]
# Word: things, Pages List: [None]
# Word: believes, Pages List: [None]
# Word: logical, Pages List: [None]
# Word: thought, Pages List: [None]
# Word: utilized, Pages List: [None]
# Word: most, Pages List: [None]
# Word: quite, Pages List: [None]
# Word: frustrating, Pages List: [None]
# Word: blind, Pages List: [None]
# Word: truth, Pages List: [None]
# Word: tends, Pages List: [None]
# Word: ignore, Pages List: [None]
# Word: input, Pages List: [None]
# Word: specifically, Pages List: [None]
# Word: current, Pages List: [None]
# Word: yields, Pages List: [None]
# Word: high, Pages List: [None]
# Word: level, Pages List: [None]
# Word: see, Pages List: [None]
# Word: implementations, Pages List: [None, None]
# Word: best, Pages List: [None]
# Word: our, Pages List: [None]
# Word: sun, Pages List: [None]
# Word: release, Pages List: [None]
# Word: just, Pages List: [None]
# Word: bennett, Pages List: [None, None]
# Word: professor, Pages List: [None]
# Word: goldberg, Pages List: [None]
# Word: boston, Pages List: [None, None, None, None, None]
# Word: university, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: physics, Pages List: [None]
# Word: department, Pages List: [None]
# Word: 590, Pages List: [None]
# Word: commonwealth, Pages List: [None, None]
# Word: avenue, Pages List: [None]
# Word: ma, Pages List: [None, None, None, None, None, None, None, None, None, None]
# Word: 02215, Pages List: [None]
# Word: 23471, Pages List: [None]
# Word: 25, Pages List: [None, None]
# Word: aug, Pages List: [None]
# Word: 1995, Pages List: [None]
# Word: ranking, Pages List: [None]
# Word: us, Pages List: [None, None]
# Word: educational, Pages List: [None]
# Word: institutions, Pages List: [None]
# Word: massachussets, Pages List: [None]
# Word: institute, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: cambridge, Pages List: [None]
# Word: park, Pages List: [None, None]
# Word: stanford, Pages List: [None]
# Word: palo, Pages List: [None]
# Word: ca, Pages List: [None, None, None, None, None, None]
# Word: carnegie, Pages List: [None]
# Word: mellon, Pages List: [None]
# Word: pa, Pages List: [None, None, None, None, None, None, None]
# Word: texas, Pages List: [None, None, None, None, None, None, None, None, None]
# Word: austin, Pages List: [None]
# Word: ann, Pages List: [None]
# Word: arbor, Pages List: [None]
# Word: southern, Pages List: [None, None, None, None, None, None]
# Word: los, Pages List: [None, None]
# Word: angeles, Pages List: [None, None]
# Word: purdue, Pages List: [None]
# Word: west, Pages List: [None, None, None]
# Word: berkeley, Pages List: [None]
# Word: amherst, Pages List: [None, None]
# Word: princeton, Pages List: [None]
# Word: nj, Pages List: [None, None, None, None, None]
# Word: seattle, Pages List: [None]
# Word: 16, Pages List: [None]
# Word: ohio, Pages List: [None, None, None, None]
# Word: columbus, Pages List: [None]
# Word: 17, Pages List: [None]
# Word: york, Pages List: [None, None, None, None, None, None, None, None]
# Word: santa, Pages List: [None, None, None]
# Word: barbara, Pages List: [None]
# Word: 19, Pages List: [None]
# Word: minneapolis, Pages List: [None, None]
# Word: 20, Pages List: [None]
# Word: cornell, Pages List: [None]
# Word: ny, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: pennsylvania, Pages List: [None, None, None, None]
# Word: 22, Pages List: [None]
# Word: irvine, Pages List: [None]
# Word: 23, Pages List: [None]
# Word: rutgers, Pages List: [None]
# Word: georgia, Pages List: [None, None, None]
# Word: technology, Pages List: [None, None]
# Word: atlanta, Pages List: [None]
# Word: san, Pages List: [None, None, None, None, None]
# Word: diego, Pages List: [None, None]
# Word: 26, Pages List: [None]
# Word: columbia, Pages List: [None, None]
# Word: city, Pages List: [None, None, None]
# Word: duke, Pages List: [None]
# Word: nc, Pages List: [None]
# Word: 28, Pages List: [None]
# Word: tuscon, Pages List: [None]
# Word: 29, Pages List: [None]
# Word: illinois, Pages List: [None, None, None, None, None]
# Word: chicago, Pages List: [None, None, None]
# Word: suny, Pages List: [None, None, None, None, None, None]
# Word: stony, Pages List: [None]
# Word: 31, Pages List: [None]
# Word: yale, Pages List: [None]
# Word: ct, Pages List: [None]
# Word: 32, Pages List: [None]
# Word: station, Pages List: [None]
# Word: 34, Pages List: [None]
# Word: davis, Pages List: [None]
# Word: 35, Pages List: [None]
# Word: boulder, Pages List: [None]
# Word: philadelphia, Pages List: [None]
# Word: 37, Pages List: [None]
# Word: brown, Pages List: [None]
# Word: ri, Pages List: [None]
# Word: 38, Pages List: [None]
# Word: rice, Pages List: [None]
# Word: tx, Pages List: [None, None, None]
# Word: michigan, Pages List: [None, None, None, None]
# Word: east, Pages List: [None]
# Word: lansing, Pages List: [None]
# Word: 40, Pages List: [None]
# Word: gainesville, Pages List: [None]
# Word: 41, Pages List: [None]
# Word: southwestern, Pages List: [None]
# Word: lafayette, Pages List: [None]
# Word: northwestern, Pages List: [None]
# Word: il, Pages List: [None, None]
# Word: 43, Pages List: [None]
# Word: 44, Pages List: [None]
# Word: johns, Pages List: [None]
# Word: hopkins, Pages List: [None]
# Word: md, Pages List: [None, None]
# Word: 46, Pages List: [None]
# Word: louisiana, Pages List: [None, None]
# Word: baton, Pages List: [None]
# Word: rouge, Pages List: [None]
# Word: iowa, Pages List: [None, None]
# Word: ames, Pages List: [None]
# Word: cruz, Pages List: [None]
# Word: 49, Pages List: [None]
# Word: richardson, Pages List: [None]
# Word: 50, Pages List: [None]
# Word: harvard, Pages List: [None]
# Word: north, Pages List: [None, None, None, None, None, None]
# Word: chapel, Pages List: [None]
# Word: hill, Pages List: [None]
# Word: 52, Pages List: [None]
# Word: case, Pages List: [None]
# Word: western, Pages List: [None, None, None, None]
# Word: reserve, Pages List: [None]
# Word: oh, Pages List: [None, None, None, None, None, None, None]
# Word: 53, Pages List: [None]
# Word: 54, Pages List: [None]
# Word: clemson, Pages List: [None]
# Word: sc, Pages List: [None, None]
# Word: 55, Pages List: [None]
# Word: 56, Pages List: [None]
# Word: naval, Pages List: [None, None]
# Word: postgraduate, Pages List: [None, None]
# Word: 57, Pages List: [None]
# Word: washington, Pages List: [None, None, None, None, None]
# Word: mo, Pages List: [None]
# Word: 58, Pages List: [None]
# Word: 59, Pages List: [None]
# Word: 60, Pages List: [None]
# Word: knoxville, Pages List: [None]
# Word: 61, Pages List: [None]
# Word: virgina, Pages List: [None]
# Word: polytechnic, Pages List: [None, None, None]
# Word: blacksburg, Pages List: [None]
# Word: 62, Pages List: [None]
# Word: syracuse, Pages List: [None]
# Word: 63, Pages List: [None]
# Word: 64, Pages List: [None]
# Word: carolina, Pages List: [None, None, None, None]
# Word: raleigh, Pages List: [None]
# Word: 65, Pages List: [None]
# Word: william, Pages List: [None]
# Word: va, Pages List: [None, None, None, None]
# Word: 66, Pages List: [None]
# Word: northeastern, Pages List: [None]
# Word: 67, Pages List: [None]
# Word: vanderbilt, Pages List: [None]
# Word: tn, Pages List: [None, None]
# Word: 68, Pages List: [None]
# Word: rensselaer, Pages List: [None]
# Word: polytechic, Pages List: [None]
# Word: 69, Pages List: [None]
# Word: salt, Pages List: [None]
# Word: lake, Pages List: [None, None]
# Word: 70, Pages List: [None]
# Word: methodist, Pages List: [None]
# Word: 71, Pages List: [None]
# Word: 72, Pages List: [None]
# Word: eugene, Pages List: [None]
# Word: 73, Pages List: [None]
# Word: george, Pages List: [None, None]
# Word: mason, Pages List: [None]
# Word: 74, Pages List: [None]
# Word: dominion, Pages List: [None]
# Word: 75, Pages List: [None]
# Word: pullman, Pages List: [None]
# Word: 76, Pages List: [None]
# Word: california, Pages List: [None, None, None, None, None, None]
# Word: pasadena, Pages List: [None]
# Word: 77, Pages List: [None]
# Word: colorado, Pages List: [None, None]
# Word: fort, Pages List: [None]
# Word: collins, Pages List: [None]
# Word: 78, Pages List: [None]
# Word: 79, Pages List: [None]
# Word: 80, Pages List: [None]
# Word: jersey, Pages List: [None]
# Word: newark, Pages List: [None, None]
# Word: 81, Pages List: [None]
# Word: baltimore, Pages List: [None, None, None]
# Word: 82, Pages List: [None]
# Word: rhode, Pages List: [None]
# Word: kingston, Pages List: [None]
# Word: 83, Pages List: [None]
# Word: central, Pages List: [None]
# Word: orlando, Pages List: [None]
# Word: 84, Pages List: [None]
# Word: 85, Pages List: [None]
# Word: brigham, Pages List: [None]
# Word: young, Pages List: [None]
# Word: ut, Pages List: [None]
# Word: 86, Pages List: [None]
# Word: antonio, Pages List: [None]
# Word: 87, Pages List: [None]
# Word: riverside, Pages List: [None]
# Word: 88, Pages List: [None]
# Word: portland, Pages List: [None, None, None]
# Word: 89, Pages List: [None]
# Word: notre, Pages List: [None]
# Word: south, Pages List: [None, None, None, None]
# Word: 90, Pages List: [None]
# Word: oregon, Pages List: [None, None]
# Word: corvallis, Pages List: [None]
# Word: 91, Pages List: [None]
# Word: wayne, Pages List: [None]
# Word: mi, Pages List: [None]
# Word: 92, Pages List: [None]
# Word: tampa, Pages List: [None]
# Word: 93, Pages List: [None]
# Word: lexington, Pages List: [None]
# Word: 94, Pages List: [None]
# Word: 95, Pages List: [None]
# Word: stoors, Pages List: [None]
# Word: 96, Pages List: [None]
# Word: tuscaloosa, Pages List: [None]
# Word: 97, Pages List: [None]
# Word: wright, Pages List: [None]
# Word: 98, Pages List: [None]
# Word: miami, Pages List: [None, None]
# Word: 99, Pages List: [None]
# Word: brandeis, Pages List: [None]
# Word: 100, Pages List: [None]
# Word: albuquerque, Pages List: [None]
# Word: 101, Pages List: [None]
# Word: indiana, Pages List: [None, None, None, None]
# Word: bloomington, Pages List: [None]
# Word: 102, Pages List: [None]
# Word: lincoln, Pages List: [None]
# Word: 103, Pages List: [None]
# Word: 104, Pages List: [None]
# Word: dartmouth, Pages List: [None]
# Word: nh, Pages List: [None]
# Word: 105, Pages List: [None]
# Word: burlington, Pages List: [None]
# Word: 106, Pages List: [None]
# Word: stevens, Pages List: [None]
# Word: 107, Pages List: [None]
# Word: hawai, Pages List: [None]
# Word: manoa, Pages List: [None]
# Word: 108, Pages List: [None]
# Word: 109, Pages List: [None]
# Word: kent, Pages List: [None]
# Word: 110, Pages List: [None]
# Word: 111, Pages List: [None]
# Word: kansas, Pages List: [None, None]
# Word: 112, Pages List: [None]
# Word: wichita, Pages List: [None]
# Word: 113, Pages List: [None]
# Word: arizona, Pages List: [None]
# Word: 114, Pages List: [None]
# Word: air, Pages List: [None]
# Word: force, Pages List: [None]
# Word: 115, Pages List: [None]
# Word: drexel, Pages List: [None]
# Word: 116, Pages List: [None]
# Word: worcester, Pages List: [None]
# Word: 117, Pages List: [None]
# Word: arlington, Pages List: [None]
# Word: 118, Pages List: [None]
# Word: 119, Pages List: [None]
# Word: mississipi, Pages List: [None]
# Word: 120, Pages List: [None]
# Word: carbonale, Pages List: [None]
# Word: 121, Pages List: [None]
# Word: auburn, Pages List: [None]
# Word: al, Pages List: [None]
# Word: 122, Pages List: [None]
# Word: wyoming, Pages List: [None]
# Word: 123, Pages List: [None]
# Word: 124, Pages List: [None]
# Word: florida, Pages List: [None, None, None, None, None, None]
# Word: atlantic, Pages List: [None, None]
# Word: 125, Pages List: [None]
# Word: laval, Pages List: [None]
# Word: 126, Pages List: [None]
# Word: cuny, Pages List: [None, None, None]
# Word: 127, Pages List: [None]
# Word: arkansas, Pages List: [None]
# Word: 128, Pages List: [None]
# Word: 129, Pages List: [None]
# Word: dalhousie, Pages List: [None]
# Word: 130, Pages List: [None]
# Word: waikato, Pages List: [None]
# Word: 131, Pages List: [None]
# Word: 132, Pages List: [None]
# Word: northern, Pages List: [None, None]
# Word: 133, Pages List: [None]
# Word: smith, Pages List: [None]
# Word: massachusetts, Pages List: [None]
# Word: 134, Pages List: [None]
# Word: loyola, Pages List: [None, None]
# Word: 135, Pages List: [None]
# Word: denver, Pages List: [None, None]
# Word: 136, Pages List: [None]
# Word: 137, Pages List: [None]
# Word: wesleyan, Pages List: [None]
# Word: connecticut, Pages List: [None, None, None, None]
# Word: 138, Pages List: [None]
# Word: mexico, Pages List: [None, None]
# Word: 139, Pages List: [None]
# Word: 140, Pages List: [None]
# Word: fairbanks, Pages List: [None]
# Word: 141, Pages List: [None]
# Word: virginia, Pages List: [None, None, None]
# Word: 142, Pages List: [None]
# Word: 143, Pages List: [None]
# Word: research, Pages List: [None]
# Word: learning, Pages List: [None]
# Word: 144, Pages List: [None]
# Word: mississippi, Pages List: [None]
# Word: 145, Pages List: [None]
# Word: el, Pages List: [None]
# Word: paso, Pages List: [None]
# Word: 146, Pages List: [None]
# Word: las, Pages List: [None]
# Word: vegas, Pages List: [None]
# Word: 147, Pages List: [None]
# Word: claremont, Pages List: [None]
# Word: graduate, Pages List: [None]
# Word: usa, Pages List: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Word: 148, Pages List: [None]
# Word: jose, Pages List: [None]
# Word: 149, Pages List: [None]
# Word: technological, Pages List: [None]
# Word: 150, Pages List: [None]
# Word: alabama, Pages List: [None, None, None]
# Word: birmingham, Pages List: [None]
# Word: 151, Pages List: [None]
# Word: 152, Pages List: [None]
# Word: 153, Pages List: [None]
# Word: tulane, Pages List: [None]
# Word: 154, Pages List: [None]
# Word: 155, Pages List: [None]
# Word: hampton, Pages List: [None]
# Word: 156, Pages List: [None]
# Word: 157, Pages List: [None]
# Word: rochester, Pages List: [None]
# Word: 158, Pages List: [None]
# Word: flushing, Pages List: [None]
# Word: 159, Pages List: [None]
# Word: edinboro, Pages List: [None]
# Word: 160, Pages List: [None]
# Word: iona, Pages List: [None]
# Word: 161, Pages List: [None]
# Word: athens, Pages List: [None]
# Word: 162, Pages List: [None]
# Word: 163, Pages List: [None]
# Word: national, Pages List: [None, None]
# Word: institutes, Pages List: [None]
# Word: 164, Pages List: [None]
# Word: davidson, Pages List: [None]
# Word: 165, Pages List: [None]
# Word: edwardsw, Pages List: [None]
# Word: 166, Pages List: [None]
# Word: 167, Pages List: [None]
# Word: maths, Pages List: [None]
# Word: minneso, Pages List: [None]
# Word: 168, Pages List: [None]
# Word: charlotte, Pages List: [None]
# Word: 169, Pages List: [None]
# Word: 170, Pages List: [None]
# Word: 171, Pages List: [None]
# Word: defense, Pages List: [None]
# Word: dc, Pages List: [None]
# Word: 172, Pages List: [None]
# Word: glassboro, Pages List: [None]
# Word: 173, Pages List: [None]
# Word: royal, Pages List: [None]
# Word: military, Pages List: [None, None]
# Word: science, Pages List: [None]
# Word: 174, Pages List: [None]
# Word: union, Pages List: [None]
# Word: 175, Pages List: [None]
# Word: sweden, Pages List: [None]
# Word: 176, Pages List: [None]
# Word: suffolk, Pages List: [None]
# Word: 177, Pages List: [None]
# Word: maine, Pages List: [None]
# Word: 178, Pages List: [None]
# Word: 179, Pages List: [None]
# Word: 180, Pages List: [None]
# Word: williams, Pages List: [None]
# Word: 181, Pages List: [None]
# Word: temple, Pages List: [None]
# Word: 182, Pages List: [None]
# Word: montclair, Pages List: [None]
# Word: 183, Pages List: [None]
# Word: queens, Pages List: [None]
# Word: 184, Pages List: [None]
# Word: pacific, Pages List: [None]
# Word: lutheran, Pages List: [None]
# Word: 185, Pages List: [None]
# Word: butler, Pages List: [None]
# Word: 186, Pages List: [None]
# Word: marymount, Pages List: [None]
# Word: 187, Pages List: [None]
# Word: colegio, Pages List: [None]
# Word: de, Pages List: [None]
# Word: postgraduados, Pages List: [None]
# Word: 188, Pages List: [None]
# Word: 189, Pages List: [None]
# Word: georgetown, Pages List: [None]
# Word: 190, Pages List: [None]
# Word: minnesota, Pages List: [None]
# Word: 191, Pages List: [None]
# Word: 192, Pages List: [None]
# Word: 193, Pages List: [None]
# Word: fullerton, Pages List: [None, None]
# Word: 194, Pages List: [None]
# Word: brooklyn, Pages List: [None]
# Word: 195, Pages List: [None]
# Word: bowling, Pages List: [None]
# Word: green, Pages List: [None]
# Word: 196, Pages List: [None]
# Word: youngstown, Pages List: [None]
# Word: 197, Pages List: [None]
# Word: ande, Pages List: [None]
# Word: cancer, Pages List: [None]
# Word: cen, Pages List: [None]
# Word: 198, Pages List: [None]
# Word: 199, Pages List: [None]
# Word: unc, Pages List: [None]
# Word: greensboro, Pages List: [None]
# Word: 200, Pages List: [None]
# Word: emory, Pages List: [None]
# Word: ga, Pages List: [None]
# Word: 201, Pages List: [None]
# Word: toledo, Pages List: [None]
# Word: 202, Pages List: [None]
# Word: humboldt, Pages List: [None]
# Word: 203, Pages List: [None]
# Word: hayward, Pages List: [None]
# Word: 204, Pages List: [None]
# Word: muskingum, Pages List: [None]
# Word: 205, Pages List: [None]
# Word: 206, Pages List: [None]
# Word: southwest, Pages List: [None]
# Word: 207, Pages List: [None]
# Word: maryville, Pages List: [None]
# Word: tennessee, Pages List: [None, None]
# Word: 208, Pages List: [None]
# Word: 209, Pages List: [None]
# Word: 210, Pages List: [None]
# Word: bentley, Pages List: [None]
# Word: 211, Pages List: [None]
# Word: united, Pages List: [None]
# Word: states, Pages List: [None]
# Word: academy, Pages List: [None]
# Word: 212, Pages List: [None]
# Word: wilkes, Pages List: [None]
# Word: 213, Pages List: [None]
# Word: 214, Pages List: [None]
# Word: 215, Pages List: [None]
# Word: space, Pages List: [None, None]
# Word: 216, Pages List: [None]
# Word: 217, Pages List: [None]
# Word: barnard, Pages List: [None]
# Word: baruch, Pages List: [None]
# Word: 218, Pages List: [None]
# Word: christopher, Pages List: [None]
# Word: newport, Pages List: [None]
# Word: 219, Pages List: [None]
# Word: lecce, Pages List: [None]
# Word: 220, Pages List: [None]
# Word: clarkson, Pages List: [None]
# Word: 221, Pages List: [None]
# Word: duluth, Pages List: [None]
# Word: 222, Pages List: [None]
# Word: 223, Pages List: [None]
# Word: 224, Pages List: [None]
# Word: district, Pages List: [None]
# Word: 225, Pages List: [None]
# Word: orleans, Pages List: [None]
# Word: 226, Pages List: [None]
# Word: lehigh, Pages List: [None]
# Word: 227, Pages List: [None]
# Word: mn, Pages List: [None]
# Word: 228, Pages List: [None]
# Word: 229, Pages List: [None]
# Word: emporia, Pages List: [None]
# Word: ks, Pages List: [None]
# Word: 230, Pages List: [None]
# Word: francisco, Pages List: [None]
# Word: 231, Pages List: [None]
# Word: hunter, Pages List: [None]
# Word: 232, Pages List: [None]
# Word: school, Pages List: [None]
# Word: mines, Pages List: [None]
# Word: 233, Pages List: [None]
# Word: carson, Pages List: [None]
# Word: 234, Pages List: [None]
# Word: saint, Pages List: [None]
# Word: 235, Pages List: [None]
# Word: cloud, Pages List: [None]
# Word: 236, Pages List: [None]
# Word: moorpark, Pages List: [None]
# Word: 237, Pages List: [None]
# Word: staten, Pages List: [None]
# Word: 238, Pages List: [None]
# Word: memphis, Pages List: [None]
# Word: 239, Pages List: [None]
# Word: international, Pages List: [None]
# Word: 240, Pages List: [None]
# Word: tech, Pages List: [None]
# Word: 241, Pages List: [None]
# Word: 242, Pages List: [None]
# Word: oshkosh, Pages List: [None]
# Word: 243, Pages List: [None]
# Word: paltz, Pages List: [None]
# Word: 244, Pages List: [None]
# Word: melbour, Pages List: [None]
# Word: 245, Pages List: [None]
# Word: dakota, Pages List: [None]
# Word: 246, Pages List: [None]
# Word: 247, Pages List: [None]
# Word: centre, Pages List: [None]
# Word: kentucky, Pages List: [None]
# Word: 248, Pages List: [None]
# Word: 249, Pages List: [None]
# Word: baylor, Pages List: [None]
# Word: 250, Pages List: [None]
# Word: 251, Pages List: [None]
# Word: depaul, Pages List: [None]
# Word: 252, Pages List: [None]
# Word: 253, Pages List: [None]
# Word: rolla, Pages List: [None]
# Word: 254, Pages List: [None]
# Word: 255, Pages List: [None]
# Word: willamette, Pages List: [None]
# Word: 256, Pages List: [None]
# Word: res, Pages List: [None]
# Word: inst, Pages List: [None]
# Word: adv, Pages List: [None]
# Word: comp, Pages List: [None]
# Word: 257, Pages List: [None]
# Word: bell, Pages List: [None]
# Word: 258, Pages List: [None]
# Word: la, Pages List: [None, None]
# Word: jolla, Pages List: [None]
# Word: 259, Pages List: [None]
# Word: eau, Pages List: [None]
# Word: clare, Pages List: [None]
# Word: 260, Pages List: [None]
# Word: cleveland, Pages List: [None]
# Word: 261, Pages List: [None]
# Word: 262, Pages List: [None]
# Word: michelson, Pages List: [None]
# Word: 263, Pages List: [None]
# Word: towson, Pages List: [None]
# Word: 264, Pages List: [None]
# Word: denton, Pages List: [None]
# Word: 265, Pages List: [None]
# Word: eastern, Pages List: [None]
# Word: 266, Pages List: [None]
# Word: clara, Pages List: [None]
# Word: 267, Pages List: [None]
# Word: lycoming, Pages List: [None]
# Word: 268, Pages List: [None]
# Word: macalester, Pages List: [None]
# Word: 269, Pages List: [None]
# Word: 270, Pages List: [None]
# Word: 271, Pages List: [None]
# Word: helsinki, Pages List: [None]
# Word: finland, Pages List: [None]
# Word: 272, Pages List: [None]
# Word: clark, Pages List: [None]
# Word: 273, Pages List: [None]
# Word: 274, Pages List: [None]
# Word: wier, Pages List: [None]
# Word: 275, Pages List: [None]
# Word: 276, Pages List: [None]
# Word: randolph, Pages List: [None]
# Word: macon, Pages List: [None]
# Word: 277, Pages List: [None]
# Word: 278, Pages List: [None]
# Word: rockefeller, Pages List: [None]
# Word: 279, Pages List: [None]
# Word: brock, Pages List: [None]
# Word: 280, Pages List: [None]
# Word: clear, Pages List: [None]
# Word: 281, Pages List: [None]
# Word: christian, Pages List: [None]
# Word: 282, Pages List: [None]
# Word: univ, Pages List: [None]
# Word: indianapolis, Pages List: [None]
# Word: 283, Pages List: [None]
# Word: telescope, Pages List: [None]
# Word: 284, Pages List: [None]
# Word: oberlin, Pages List: [None]
# Word: 285, Pages List: [None]
# Word: harvey, Pages List: [None]
# Word: mudd, Pages List: [None]
# Word: 286, Pages List: [None]
# Word: huntsville, Pages List: [None]
# Word: 287, Pages List: [None]
# Word: 288, Pages List: [None]
# Word: westminister, Pages List: [None]
# Word: 289, Pages List: [None]
# Word: 290, Pages List: [None]
# Word: barry, Pages List: [None]
#
# Relevant Page IDs for Query: []
# Best Fitness Value: 0.9915064143542314

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# Ground truth for relevant documents, you can replace this with your actual ground truth
# Format: {query_id: [list of relevant document IDs]}
ground_truth = {
    'query_1': [1, 2, 3],
    'query_2': [4, 5],


# Retrieved documents for each query
# Format: {query_id: [list of retrieved document IDs]}
retrieved_documents = {
    'query_1': [1, 3, 4],
    'query_2': [4, 5, 6],

}

# Initialize empty lists for ground truth labels and retrieved document labels
ground_truth_labels = []
retrieved_doc_labels = []

# Align the data
for query_id, relevant_docs in ground_truth.items():
    retrieved_docs = retrieved_documents.get(query_id, [])
    for doc_id in retrieved_docs:
        if doc_id in relevant_docs:
            ground_truth_labels.append(1)  # Document is relevant
        else:
            ground_truth_labels.append(0)  # Document is not relevant
        retrieved_doc_labels.append(1 if doc_id in retrieved_docs else 0)

# Calculate evaluation metrics
accuracy = accuracy_score(ground_truth_labels, retrieved_doc_labels)
recall = recall_score(ground_truth_labels, retrieved_doc_labels)
precision = precision_score(ground_truth_labels, retrieved_doc_labels)
f1 = f1_score(ground_truth_labels, retrieved_doc_labels)

print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.6666666666666666
# Recall: 1.0
# Precision: 0.6666666666666666
# F1 Score: 0.8

# %%
# Function to preprocess the document content
def preprocess_document(document_content):
    # Tokenize the content by splitting on spaces (you can use more advanced tokenization)
    words = document_content.split()

    # Remove stop words, special characters, and sentence delimiters
    stop_words = set(["the", "and", "is", "in", "it", "an", "to", "of", "as", "by"])
    words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

    # Calculate total weight (word count) and total count word
    total_weight = len(words)
    total_count_word = len(set(words))

    return total_weight, total_count_word, words

# Function to perform document indexing
def document_indexing(dataset_path):
    pages_information = {}
    words_information = {}

    for root, _, files in os.walk(dataset_path):
        for file_name in files:
            if file_name.endswith(".txt"):
                with open(os.path.join(root, file_name), 'r', encoding='utf-8') as file:
                    document_content = file.read()
                    total_weight, total_count_word, words = preprocess_document(document_content)

                    page_id = get_page_id(file_name)
                    page_name = get_page_name(file_name)

                    # Store page information
                    pages_information[page_id] = {
                        "page_name": page_name,
                        "total_weight": total_weight,
                        "total_count_word": total_count_word,
                    }

                    # Update words information
                    for word in words:
                        if word not in words_information:
                            words_information[word] = {"pages_list": [page_id]}
                        else:
                            words_information[word]["pages_list"].append(page_id)

    # Replace None with the actual count of occurrences
    for word, info in words_information.items():
        info["pages_list"] = len(info["pages_list"])

    return pages_information, words_information

# Function to print words information in table format
def print_words_information(words_information):
    print("\nWords Information:")
    print("{:<20} {}".format("Word", "Document IDs"))
    for word, info in words_information.items():
        print("{:<20} {}".format(word, info["pages_list"]))

# ... (rest of the code remains the same)

# Print words information
print_words_information(words_information)

# Function to perform query search
def query_search(user_query, words_information):
    query_words = user_query.lower().split()
    id_list = []

    for word in query_words:
        if word in words_information:
            id_list.extend(words_information[word]["pages_list"])

    return list(set(id_list))  # Remove duplicates

# Function to perform the modified GA procedure
def modified_genetic_algorithm(population_size, num_iterations):
    # Replace this with your actual genetic algorithm logic
    # Here, we'll just generate random fitness values for demonstration
    fitness_values = [random.random() for _ in range(population_size)]

    # Return the best fitness value after the specified number of iterations
    best_fitness = max(fitness_values)
    return best_fitness

# Example usage
if __name__ == "__main__":
    dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"

    # Algorithm 1: Document Indexing
    pages_information, words_information = document_indexing(dataset_path)

    # Algorithm 2: Query Search
    user_query = "Required"
    relevant_page_ids = query_search(user_query, words_information)

    # Algorithm 3: Modified Genetic Algorithm
    population_size = 50
    num_iterations = 15
    best_fitness = modified_genetic_algorithm(population_size, num_iterations)

    # Print results
    print("Pages Information:")
    for page_id, page_info in pages_information.items():
        print(f"Page ID: {page_id}, Page Name: {page_info['page_name']}, Total Weight: {page_info['total_weight']}, Total Count Word: {page_info['total_count_word']}")

    print("\nWords Information:")
    for word, word_info in words_information.items():
        print(f"Word: {word}, Pages List: {word_info['pages_list']}")

    print("\nRelevant Page IDs for Query:", relevant_page_ids)
    print("Best Fitness Value:", best_fitness)
# Out:
# Words Information:
# Word                 Document IDs
# 14                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# jan                  [None, None, None, None, None, None, None]
# 1997                 [None, None, None, None, None, None, None]
# gmt                  [None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 15                   [None, None, None, None, None, None, None, None, None, None, None, None]
# feb                  [None]
# 1996                 [None, None, None]
# 3082                 [None]
# problem              [None, None, None, None, None]
# 1                    [None, None, None, None, None, None, None, None, None, None, None, None]
# part                 [None, None, None, None, None, None, None, None]
# a                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# though               [None, None]
# not                  [None, None, None, None, None]
# for                  [None, None, None, None, None, None, None, None, None, None, None, None]
# longer               [None]
# but                  [None, None, None, None, None, None, None]
# was                  [None]
# b                    [None, None]
# grandparent          [None]
# parent               [None, None, None, None, None, None]
# x                    [None, None, None, None, None, None, None]
# mother               [None, None]
# y                    [None, None, None]
# if                   [None, None, None, None, None, None, None]
# female               [None]
# sibling              [None, None]
# different            [None]
# person               [None, None, None, None]
# with                 [None, None, None, None, None, None, None]
# same                 [None, None]
# sister               [None, None]
# law                  [None, None]
# either               [None, None, None]
# or                   [None, None, None, None, None, None, None]
# wife                 [None, None]
# c                    [None]
# that                 [None, None, None]
# this                 [None, None, None]
# often                [None]
# go                   [None]
# into                 [None]
# infinite             [None]
# you                  [None, None, None]
# ask                  [None, None, None]
# query                [None]
# whose                [None]
# answer               [None, None, None]
# should               [None]
# be                   [None, None, None, None, None, None, None]
# find                 [None, None]
# spouse               [None, None]
# unmarried            [None]
# who                  [None]
# will                 [None]
# return               [None, None]
# infinitely           [None]
# many                 [None, None]
# times                [None]
# on                   [None, None, None, None, None, None, None, None]
# diana                [None, None, None]
# requesting           [None, None]
# another              [None, None, None]
# use                  [None]
# auxiliary            [None]
# predicate            [None]
# state                [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# fact                 [None]
# once                 [None, None, None]
# each                 [None, None, None]
# then                 [None, None]
# define               [None]
# terms                [None]
# 2                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# run                  [None]
# backwards            [None]
# split                [None]
# last                 [None, None, None, None, None]
# element              [None, None, None]
# from                 [None, None, None, None]
# rest                 [None]
# them                 [None]
# connected            [None, None]
# other                [None, None, None, None, None]
# more                 [None, None, None]
# straightforward      [None]
# take                 [None, None, None]
# off                  [None, None]
# all                  [None, None, None, None]
# reconnect            [None]
# binds                [None, None, None]
# r                    [None, None]
# rotates              [None]
# succeeds             [None]
# applies              [None]
# k                    [None, None, None]
# rotations            [None]
# returning            [None]
# k1                   [None]
# m                    [None, None, None, None]
# rotation             [None]
# l                    [None, None]
# keeps                [None]
# rotating             [None]
# backtrackings        [None]
# are                  [None, None, None, None, None, None]
# 4                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# n                    [None, None]
# n1                   [None]
# e                    [None]
# 522                  [None]
# 08                   [None]
# 2578                 [None]
# atomic               [None, None]
# transaction          [None, None, None, None, None, None, None]
# like                 [None]
# signing              [None]
# contract             [None]
# two                  [None, None]
# they                 [None]
# both                 [None, None, None]
# fig                  [None, None, None, None, None, None, None]
# withdraw             [None]
# my                   [None]
# deposit              [None]
# your                 [None]
# model                [None]
# independent          [None]
# which                [None, None, None, None, None, None]
# can                  [None, None, None, None, None]
# fail                 [None]
# at                   [None, None, None, None, None, None, None, None, None, None, None, None, None]
# random               [None]
# communication        [None]
# reliable             [None]
# timeout              [None]
# stable               [None, None, None]
# storage              [None, None, None, None]
# 3                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# types                [None]
# ram                  [None]
# power                [None]
# machine              [None]
# crashes              [None, None]
# disk                 [None, None]
# survives             [None]
# cpu                  [None]
# failures             [None, None]
# lost                 [None]
# head                 [None]
# designed             [None, None, None]
# survive              [None]
# any                  [None, None]
# primitive            [None]
# start                [None]
# terminate            [None]
# commit               [None, None, None, None, None, None, None]
# kill                 [None]
# restore              [None]
# old                  [None, None, None]
# value                [None]
# read                 [None]
# write                [None, None]
# properties           [None]
# transactions         [None, None, None, None]
# indivisible          [None]
# outside              [None]
# maintain             [None]
# system               [None, None, None, None]
# invariants           [None]
# no                   [None, None, None]
# interference         [None]
# concurrent           [None, None, None]
# committed            [None, None]
# changes              [None, None]
# permanent            [None]
# append               [None]
# file                 [None, None]
# consistent           [None, None]
# conservation         [None]
# money                [None]
# isolated             [None]
# serializable         [None]
# serial               [None]
# serialized           [None]
# ok                   [None, None]
# since                [None]
# values               [None, None]
# illegal              [None]
# nested               [None]
# may                  [None]
# execute              [None]
# one                  [None, None]
# subtransactions      [None]
# when                 [None, None, None]
# subtransaction       [None, None]
# its                  [None, None]
# results              [None, None]
# visible              [None]
# must                 [None]
# implementation       [None]
# how                  [None, None, None]
# undo                 [None]
# intermediate         [None]
# updates              [None]
# private              [None, None]
# workspace            [None, None]
# give                 [None]
# copy                 [None]
# needed               [None]
# writeahead           [None]
# log                  [None, None, None, None]
# intentions           [None]
# files                [None, None]
# actually             [None]
# modified             [None]
# place                [None]
# before               [None, None]
# record               [None, None]
# written              [None, None]
# new                  [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# after                [None]
# changed              [None]
# undone               [None]
# also                 [None, None, None]
# used                 [None, None]
# recovering           [None]
# protocol             [None, None, None]
# atomically           [None]
# why                  [None]
# general              [None]
# paradox              [None]
# generals             [None]
# want                 [None]
# agree                [None, None]
# time                 [None]
# even                 [None]
# some                 [None]
# messengers           [None]
# do                   [None]
# get                  [None]
# impossibility        [None]
# assume               [None]
# exist                [None]
# shortest             [None]
# sequence             [None]
# msgs                 [None, None]
# goal                 [None]
# sites                [None]
# abort                [None]
# relax                [None]
# req                  [None]
# number               [None, None]
# bounded              [None]
# fixed                [None]
# 337                  [None]
# 18                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# dec                  [None, None]
# 6459                 [None]
# column               [None]
# heading              [None]
# means                [None]
# assignment           [None]
# worth                [None]
# total                [None, None]
# points               [None, None]
# extra                [None, None]
# hmwk1                [None]
# hmwk2                [None]
# hmwk3                [None]
# hmwk4                [None]
# mid                  [None]
# hmwk5                [None]
# hmwk6                [None]
# hmwk7                [None]
# hmwk8                [None]
# hmwk9                [None]
# final                [None]
# 7                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 39                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 51                   [None, None]
# 5                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 8                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 21                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 6                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 27                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 9                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 11                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 33                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 13                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 45                   [None, None, None, None, None, None, None]
# 10                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 12                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 36                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 24                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 30                   [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 42                   [None, None, None, None, None, None, None, None, None, None]
# 0                    [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 48                   [None, None]
# 47                   [None, None]
# 1396                 [None]
# sep                  [None]
# name                 [None, None]
# username             [None]
# known                [None]
# address              [None]
# blau                 [None]
# seth                 [None]
# d                    [None, None]
# sdb5200              [None]
# carr                 [None]
# richard              [None]
# rrc8372              [None]
# diament              [None]
# judah                [None]
# michael              [None, None]
# jmd205               [None]
# elkin                [None]
# vadim                [None]
# ve201                [None]
# fuh                  [None]
# paul                 [None]
# pqf3581              [None]
# hanna                [None]
# adel                 [None]
# ah1                  [None]
# hertzmann            [None]
# aaron                [None]
# phillip              [None]
# aph201               [None]
# huggins              [None]
# patrick              [None]
# s                    [None]
# psh9057              [None]
# jawalekar            [None]
# raju                 [None]
# v                    [None, None, None, None, None]
# rvj1                 [None]
# jermyn               [None]
# ian                  [None]
# hyla                 [None]
# ihj200               [None]
# kim                  [None]
# jae                  [None]
# hwan                 [None]
# jhk5364              [None]
# llaurado             [None]
# ramon                [None]
# rql6719              [None]
# newman               [None]
# joshua               [None]
# amiel                [None]
# jqn0794              [None]
# pao                  [None]
# hkp1                 [None]
# raskin               [None]
# gabriel              [None]
# carl                 [None]
# gcr3340              [None]
# sceniak              [None]
# p                    [None, None]
# mps1707              [None]
# singer               [None]
# eric                 [None]
# lee                  [None]
# els3339              [None]
# wu                   [None]
# xiangyang            [None]
# xqw5048              [None]
# 09                   [None]
# 1994                 [None]
# 2709                 [None]
# user                 [None]
# commands             [None]
# arthur               [None, None, None, None, None, None]
# intelligence         [None]
# language             [None]
# process              [None, None, None, None]
# tactile              [None]
# audible              [None]
# express              [None]
# purpose              [None]
# interacting          [None]
# synopsis             [None, None]
# play                 [None, None]
# availability         [None]
# version              [None]
# command              [None]
# available            [None]
# tem                  [None]
# software             [None]
# installation         [None]
# refer                [None]
# installing           [None]
# sunos                [None]
# information          [None]
# install              [None]
# invoke               [None]
# description          [None]
# invoked              [None]
# four                 [None]
# major                [None]
# involves             [None]
# output               [None]
# depends              [None]
# complicated          [None]
# way                  [None, None]
# sensory              [None]
# options              [None]
# option               [None, None, None, None]
# allows               [None]
# dormant              [None]
# period               [None]
# temporarily          [None]
# suspends             [None]
# processes            [None]
# food                 [None]
# specify              [None]
# calories             [None]
# color                [None]
# q                    [None]
# operating            [None]
# wide                 [None]
# ranging              [None]
# field                [None]
# examples             [None]
# include              [None]
# early                [None]
# morning              [None]
# programming          [None]
# sessions             [None]
# porch                [None]
# portable             [None]
# late                 [None]
# night                [None]
# doodling             [None]
# unreadable           [None]
# mix                  [None]
# print                [None]
# script               [None]
# ubiquitous           [None]
# spiral               [None]
# bound                [None]
# college              [None, None, None, None, None, None, None]
# recently             [None]
# installed            [None]
# significantly        [None]
# upgraded             [None]
# now                  [None]
# forevermore          [None]
# includes             [None]
# pipe                 [None]
# result               [None]
# successful           [None]
# execution            [None]
# happiness            [None]
# bugs                 [None]
# initiated            [None]
# given                [None]
# there                [None]
# easy                 [None]
# transfer             [None]
# operations           [None]
# especially           [None]
# true                 [None]
# reading              [None]
# considered           [None]
# work                 [None]
# unusual              [None]
# propensity           [None]
# think                [None]
# things               [None]
# believes             [None]
# logical              [None]
# thought              [None]
# utilized             [None]
# most                 [None]
# quite                [None]
# frustrating          [None]
# blind                [None]
# truth                [None]
# tends                [None]
# ignore               [None]
# input                [None]
# specifically         [None]
# current              [None]
# yields               [None]
# high                 [None]
# level                [None]
# see                  [None]
# implementations      [None, None]
# best                 [None]
# our                  [None]
# sun                  [None]
# release              [None]
# just                 [None]
# bennett              [None, None]
# professor            [None]
# goldberg             [None]
# boston               [None, None, None, None, None]
# university           [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# physics              [None]
# department           [None]
# 590                  [None]
# commonwealth         [None, None]
# avenue               [None]
# ma                   [None, None, None, None, None, None, None, None, None, None]
# 02215                [None]
# 23471                [None]
# 25                   [None, None]
# aug                  [None]
# 1995                 [None]
# ranking              [None]
# us                   [None, None]
# educational          [None]
# institutions         [None]
# massachussets        [None]
# institute            [None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# cambridge            [None]
# park                 [None, None]
# stanford             [None]
# palo                 [None]
# ca                   [None, None, None, None, None, None]
# carnegie             [None]
# mellon               [None]
# pa                   [None, None, None, None, None, None, None]
# texas                [None, None, None, None, None, None, None, None, None]
# austin               [None]
# ann                  [None]
# arbor                [None]
# southern             [None, None, None, None, None, None]
# los                  [None, None]
# angeles              [None, None]
# purdue               [None]
# west                 [None, None, None]
# berkeley             [None]
# amherst              [None, None]
# princeton            [None]
# nj                   [None, None, None, None, None]
# seattle              [None]
# 16                   [None]
# ohio                 [None, None, None, None]
# columbus             [None]
# 17                   [None]
# york                 [None, None, None, None, None, None, None, None]
# santa                [None, None, None]
# barbara              [None]
# 19                   [None]
# minneapolis          [None, None]
# 20                   [None]
# cornell              [None]
# ny                   [None, None, None, None, None, None, None, None, None, None, None, None, None]
# pennsylvania         [None, None, None, None]
# 22                   [None]
# irvine               [None]
# 23                   [None]
# rutgers              [None]
# georgia              [None, None, None]
# technology           [None, None]
# atlanta              [None]
# san                  [None, None, None, None, None]
# diego                [None, None]
# 26                   [None]
# columbia             [None, None]
# city                 [None, None, None]
# duke                 [None]
# nc                   [None]
# 28                   [None]
# tuscon               [None]
# 29                   [None]
# illinois             [None, None, None, None, None]
# chicago              [None, None, None]
# suny                 [None, None, None, None, None, None]
# stony                [None]
# 31                   [None]
# yale                 [None]
# ct                   [None]
# 32                   [None]
# station              [None]
# 34                   [None]
# davis                [None]
# 35                   [None]
# boulder              [None]
# philadelphia         [None]
# 37                   [None]
# brown                [None]
# ri                   [None]
# 38                   [None]
# rice                 [None]
# tx                   [None, None, None]
# michigan             [None, None, None, None]
# east                 [None]
# lansing              [None]
# 40                   [None]
# gainesville          [None]
# 41                   [None]
# southwestern         [None]
# lafayette            [None]
# northwestern         [None]
# il                   [None, None]
# 43                   [None]
# 44                   [None]
# johns                [None]
# hopkins              [None]
# md                   [None, None]
# 46                   [None]
# louisiana            [None, None]
# baton                [None]
# rouge                [None]
# iowa                 [None, None]
# ames                 [None]
# cruz                 [None]
# 49                   [None]
# richardson           [None]
# 50                   [None]
# harvard              [None]
# north                [None, None, None, None, None, None]
# chapel               [None]
# hill                 [None]
# 52                   [None]
# case                 [None]
# western              [None, None, None, None]
# reserve              [None]
# oh                   [None, None, None, None, None, None, None]
# 53                   [None]
# 54                   [None]
# clemson              [None]
# sc                   [None, None]
# 55                   [None]
# 56                   [None]
# naval                [None, None]
# postgraduate         [None, None]
# 57                   [None]
# washington           [None, None, None, None, None]
# mo                   [None]
# 58                   [None]
# 59                   [None]
# 60                   [None]
# knoxville            [None]
# 61                   [None]
# virgina              [None]
# polytechnic          [None, None, None]
# blacksburg           [None]
# 62                   [None]
# syracuse             [None]
# 63                   [None]
# 64                   [None]
# carolina             [None, None, None, None]
# raleigh              [None]
# 65                   [None]
# william              [None]
# va                   [None, None, None, None]
# 66                   [None]
# northeastern         [None]
# 67                   [None]
# vanderbilt           [None]
# tn                   [None, None]
# 68                   [None]
# rensselaer           [None]
# polytechic           [None]
# 69                   [None]
# salt                 [None]
# lake                 [None, None]
# 70                   [None]
# methodist            [None]
# 71                   [None]
# 72                   [None]
# eugene               [None]
# 73                   [None]
# george               [None, None]
# mason                [None]
# 74                   [None]
# dominion             [None]
# 75                   [None]
# pullman              [None]
# 76                   [None]
# california           [None, None, None, None, None, None]
# pasadena             [None]
# 77                   [None]
# colorado             [None, None]
# fort                 [None]
# collins              [None]
# 78                   [None]
# 79                   [None]
# 80                   [None]
# jersey               [None]
# newark               [None, None]
# 81                   [None]
# baltimore            [None, None, None]
# 82                   [None]
# rhode                [None]
# kingston             [None]
# 83                   [None]
# central              [None]
# orlando              [None]
# 84                   [None]
# 85                   [None]
# brigham              [None]
# young                [None]
# ut                   [None]
# 86                   [None]
# antonio              [None]
# 87                   [None]
# riverside            [None]
# 88                   [None]
# portland             [None, None, None]
# 89                   [None]
# notre                [None]
# south                [None, None, None, None]
# 90                   [None]
# oregon               [None, None]
# corvallis            [None]
# 91                   [None]
# wayne                [None]
# mi                   [None]
# 92                   [None]
# tampa                [None]
# 93                   [None]
# lexington            [None]
# 94                   [None]
# 95                   [None]
# stoors               [None]
# 96                   [None]
# tuscaloosa           [None]
# 97                   [None]
# wright               [None]
# 98                   [None]
# miami                [None, None]
# 99                   [None]
# brandeis             [None]
# 100                  [None]
# albuquerque          [None]
# 101                  [None]
# indiana              [None, None, None, None]
# bloomington          [None]
# 102                  [None]
# lincoln              [None]
# 103                  [None]
# 104                  [None]
# dartmouth            [None]
# nh                   [None]
# 105                  [None]
# burlington           [None]
# 106                  [None]
# stevens              [None]
# 107                  [None]
# hawai                [None]
# manoa                [None]
# 108                  [None]
# 109                  [None]
# kent                 [None]
# 110                  [None]
# 111                  [None]
# kansas               [None, None]
# 112                  [None]
# wichita              [None]
# 113                  [None]
# arizona              [None]
# 114                  [None]
# air                  [None]
# force                [None]
# 115                  [None]
# drexel               [None]
# 116                  [None]
# worcester            [None]
# 117                  [None]
# arlington            [None]
# 118                  [None]
# 119                  [None]
# mississipi           [None]
# 120                  [None]
# carbonale            [None]
# 121                  [None]
# auburn               [None]
# al                   [None]
# 122                  [None]
# wyoming              [None]
# 123                  [None]
# 124                  [None]
# florida              [None, None, None, None, None, None]
# atlantic             [None, None]
# 125                  [None]
# laval                [None]
# 126                  [None]
# cuny                 [None, None, None]
# 127                  [None]
# arkansas             [None]
# 128                  [None]
# 129                  [None]
# dalhousie            [None]
# 130                  [None]
# waikato              [None]
# 131                  [None]
# 132                  [None]
# northern             [None, None]
# 133                  [None]
# smith                [None]
# massachusetts        [None]
# 134                  [None]
# loyola               [None, None]
# 135                  [None]
# denver               [None, None]
# 136                  [None]
# 137                  [None]
# wesleyan             [None]
# connecticut          [None, None, None, None]
# 138                  [None]
# mexico               [None, None]
# 139                  [None]
# 140                  [None]
# fairbanks            [None]
# 141                  [None]
# virginia             [None, None, None]
# 142                  [None]
# 143                  [None]
# research             [None]
# learning             [None]
# 144                  [None]
# mississippi          [None]
# 145                  [None]
# el                   [None]
# paso                 [None]
# 146                  [None]
# las                  [None]
# vegas                [None]
# 147                  [None]
# claremont            [None]
# graduate             [None]
# usa                  [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 148                  [None]
# jose                 [None]
# 149                  [None]
# technological        [None]
# 150                  [None]
# alabama              [None, None, None]
# birmingham           [None]
# 151                  [None]
# 152                  [None]
# 153                  [None]
# tulane               [None]
# 154                  [None]
# 155                  [None]
# hampton              [None]
# 156                  [None]
# 157                  [None]
# rochester            [None]
# 158                  [None]
# flushing             [None]
# 159                  [None]
# edinboro             [None]
# 160                  [None]
# iona                 [None]
# 161                  [None]
# athens               [None]
# 162                  [None]
# 163                  [None]
# national             [None, None]
# institutes           [None]
# 164                  [None]
# davidson             [None]
# 165                  [None]
# edwardsw             [None]
# 166                  [None]
# 167                  [None]
# maths                [None]
# minneso              [None]
# 168                  [None]
# charlotte            [None]
# 169                  [None]
# 170                  [None]
# 171                  [None]
# defense              [None]
# dc                   [None]
# 172                  [None]
# glassboro            [None]
# 173                  [None]
# royal                [None]
# military             [None, None]
# science              [None]
# 174                  [None]
# union                [None]
# 175                  [None]
# sweden               [None]
# 176                  [None]
# suffolk              [None]
# 177                  [None]
# maine                [None]
# 178                  [None]
# 179                  [None]
# 180                  [None]
# williams             [None]
# 181                  [None]
# temple               [None]
# 182                  [None]
# montclair            [None]
# 183                  [None]
# queens               [None]
# 184                  [None]
# pacific              [None]
# lutheran             [None]
# 185                  [None]
# butler               [None]
# 186                  [None]
# marymount            [None]
# 187                  [None]
# colegio              [None]
# de                   [None]
# postgraduados        [None]
# 188                  [None]
# 189                  [None]
# georgetown           [None]
# 190                  [None]
# minnesota            [None]
# 191                  [None]
# 192                  [None]
# 193                  [None]
# fullerton            [None, None]
# 194                  [None]
# brooklyn             [None]
# 195                  [None]
# bowling              [None]
# green                [None]
# 196                  [None]
# youngstown           [None]
# 197                  [None]
# ande                 [None]
# cancer               [None]
# cen                  [None]
# 198                  [None]
# 199                  [None]
# unc                  [None]
# greensboro           [None]
# 200                  [None]
# emory                [None]
# ga                   [None]
# 201                  [None]
# toledo               [None]
# 202                  [None]
# humboldt             [None]
# 203                  [None]
# hayward              [None]
# 204                  [None]
# muskingum            [None]
# 205                  [None]
# 206                  [None]
# southwest            [None]
# 207                  [None]
# maryville            [None]
# tennessee            [None, None]
# 208                  [None]
# 209                  [None]
# 210                  [None]
# bentley              [None]
# 211                  [None]
# united               [None]
# states               [None]
# academy              [None]
# 212                  [None]
# wilkes               [None]
# 213                  [None]
# 214                  [None]
# 215                  [None]
# space                [None, None]
# 216                  [None]
# 217                  [None]
# barnard              [None]
# baruch               [None]
# 218                  [None]
# christopher          [None]
# newport              [None]
# 219                  [None]
# lecce                [None]
# 220                  [None]
# clarkson             [None]
# 221                  [None]
# duluth               [None]
# 222                  [None]
# 223                  [None]
# 224                  [None]
# district             [None]
# 225                  [None]
# orleans              [None]
# 226                  [None]
# lehigh               [None]
# 227                  [None]
# mn                   [None]
# 228                  [None]
# 229                  [None]
# emporia              [None]
# ks                   [None]
# 230                  [None]
# francisco            [None]
# 231                  [None]
# hunter               [None]
# 232                  [None]
# school               [None]
# mines                [None]
# 233                  [None]
# carson               [None]
# 234                  [None]
# saint                [None]
# 235                  [None]
# cloud                [None]
# 236                  [None]
# moorpark             [None]
# 237                  [None]
# staten               [None]
# 238                  [None]
# memphis              [None]
# 239                  [None]
# international        [None]
# 240                  [None]
# tech                 [None]
# 241                  [None]
# 242                  [None]
# oshkosh              [None]
# 243                  [None]
# paltz                [None]
# 244                  [None]
# melbour              [None]
# 245                  [None]
# dakota               [None]
# 246                  [None]
# 247                  [None]
# centre               [None]
# kentucky             [None]
# 248                  [None]
# 249                  [None]
# baylor               [None]
# 250                  [None]
# 251                  [None]
# depaul               [None]
# 252                  [None]
# 253                  [None]
# rolla                [None]
# 254                  [None]
# 255                  [None]
# willamette           [None]
# 256                  [None]
# res                  [None]
# inst                 [None]
# adv                  [None]
# comp                 [None]
# 257                  [None]
# bell                 [None]
# 258                  [None]
# la                   [None, None]
# jolla                [None]
# 259                  [None]
# eau                  [None]
# clare                [None]
# 260                  [None]
# cleveland            [None]
# 261                  [None]
# 262                  [None]
# michelson            [None]
# 263                  [None]
# towson               [None]
# 264                  [None]
# denton               [None]
# 265                  [None]
# eastern              [None]
# 266                  [None]
# clara                [None]
# 267                  [None]
# lycoming             [None]
# 268                  [None]
# macalester           [None]
# 269                  [None]
# 270                  [None]
# 271                  [None]
# helsinki             [None]
# finland              [None]
# 272                  [None]
# clark                [None]
# 273                  [None]
# 274                  [None]
# wier                 [None]
# 275                  [None]
# 276                  [None]
# randolph             [None]
# macon                [None]
# 277                  [None]
# 278                  [None]
# rockefeller          [None]
# 279                  [None]
# brock                [None]
# 280                  [None]
# clear                [None]
# 281                  [None]
# christian            [None]
# 282                  [None]
# univ                 [None]
# indianapolis         [None]
# 283                  [None]
# telescope            [None]
# 284                  [None]
# oberlin              [None]
# 285                  [None]
# harvey               [None]
# mudd                 [None]
# 286                  [None]
# huntsville           [None]
# 287                  [None]
# 288                  [None]
# westminister         [None]
# 289                  [None]
# 290                  [None]
# barry                [None]
# Pages Information:
# Page ID: None, Page Name: http_^^www.cs.clemson.edu^~madhu^usa, Total Weight: 1085, Total Count Word: 649
#
# Words Information:
# Word: 14, Pages List: 16
# Word: jan, Pages List: 7
# Word: 1997, Pages List: 7
# Word: gmt, Pages List: 14
# Word: 15, Pages List: 12
# Word: feb, Pages List: 1
# Word: 1996, Pages List: 3
# Word: 3082, Pages List: 1
# Word: problem, Pages List: 5
# Word: 1, Pages List: 12
# Word: part, Pages List: 8
# Word: a, Pages List: 38
# Word: though, Pages List: 2
# Word: not, Pages List: 5
# Word: for, Pages List: 12
# Word: longer, Pages List: 1
# Word: but, Pages List: 7
# Word: was, Pages List: 1
# Word: b, Pages List: 2
# Word: grandparent, Pages List: 1
# Word: parent, Pages List: 6
# Word: x, Pages List: 7
# Word: mother, Pages List: 2
# Word: y, Pages List: 3
# Word: if, Pages List: 7
# Word: female, Pages List: 1
# Word: sibling, Pages List: 2
# Word: different, Pages List: 1
# Word: person, Pages List: 4
# Word: with, Pages List: 7
# Word: same, Pages List: 2
# Word: sister, Pages List: 2
# Word: law, Pages List: 2
# Word: either, Pages List: 3
# Word: or, Pages List: 7
# Word: wife, Pages List: 2
# Word: c, Pages List: 1
# Word: that, Pages List: 3
# Word: this, Pages List: 3
# Word: often, Pages List: 1
# Word: go, Pages List: 1
# Word: into, Pages List: 1
# Word: infinite, Pages List: 1
# Word: you, Pages List: 3
# Word: ask, Pages List: 3
# Word: query, Pages List: 1
# Word: whose, Pages List: 1
# Word: answer, Pages List: 3
# Word: should, Pages List: 1
# Word: be, Pages List: 7
# Word: find, Pages List: 2
# Word: spouse, Pages List: 2
# Word: unmarried, Pages List: 1
# Word: who, Pages List: 1
# Word: will, Pages List: 1
# Word: return, Pages List: 2
# Word: infinitely, Pages List: 1
# Word: many, Pages List: 2
# Word: times, Pages List: 1
# Word: on, Pages List: 8
# Word: diana, Pages List: 3
# Word: requesting, Pages List: 2
# Word: another, Pages List: 3
# Word: use, Pages List: 1
# Word: auxiliary, Pages List: 1
# Word: predicate, Pages List: 1
# Word: state, Pages List: 45
# Word: fact, Pages List: 1
# Word: once, Pages List: 3
# Word: each, Pages List: 3
# Word: then, Pages List: 2
# Word: define, Pages List: 1
# Word: terms, Pages List: 1
# Word: 2, Pages List: 25
# Word: run, Pages List: 1
# Word: backwards, Pages List: 1
# Word: split, Pages List: 1
# Word: last, Pages List: 5
# Word: element, Pages List: 3
# Word: from, Pages List: 4
# Word: rest, Pages List: 1
# Word: them, Pages List: 1
# Word: connected, Pages List: 2
# Word: other, Pages List: 5
# Word: more, Pages List: 3
# Word: straightforward, Pages List: 1
# Word: take, Pages List: 3
# Word: off, Pages List: 2
# Word: all, Pages List: 4
# Word: reconnect, Pages List: 1
# Word: binds, Pages List: 3
# Word: r, Pages List: 2
# Word: rotates, Pages List: 1
# Word: succeeds, Pages List: 1
# Word: applies, Pages List: 1
# Word: k, Pages List: 3
# Word: rotations, Pages List: 1
# Word: returning, Pages List: 1
# Word: k1, Pages List: 1
# Word: m, Pages List: 4
# Word: rotation, Pages List: 1
# Word: l, Pages List: 2
# Word: keeps, Pages List: 1
# Word: rotating, Pages List: 1
# Word: backtrackings, Pages List: 1
# Word: are, Pages List: 6
# Word: 4, Pages List: 31
# Word: n, Pages List: 2
# Word: n1, Pages List: 1
# Word: e, Pages List: 1
# Word: 522, Pages List: 1
# Word: 08, Pages List: 1
# ...
# Word: institute, Pages List: 14
# Word: cambridge, Pages List: 1
# Word: park, Pages List: 2
# Word: stanford, Pages List: 1
# Word: palo, Pages List: 1
# Word: ca, Pages List: 6
# Word: carnegie, Pages List: 1
# Word: mellon, Pages List: 1
# Word: pa, Pages List: 7
# Word: texas, Pages List: 9
# Word: austin, Pages List: 1
# Word: ann, Pages List: 1
# Word: arbor, Pages List: 1
# Word: southern, Pages List: 6
# Word: los, Pages List: 2
# Word: angeles, Pages List: 2
# Word: purdue, Pages List: 1
# Word: west, Pages List: 3
# Word: berkeley, Pages List: 1
# Word: amherst, Pages List: 2
# Word: princeton, Pages List: 1
# Word: nj, Pages List: 5
# Word: seattle, Pages List: 1
# Word: 16, Pages List: 1
# Word: ohio, Pages List: 4
# Word: columbus, Pages List: 1
# Word: 17, Pages List: 1
# Word: york, Pages List: 8
# Word: santa, Pages List: 3
# Word: barbara, Pages List: 1
# Word: 19, Pages List: 1
# Word: minneapolis, Pages List: 2
# Word: 20, Pages List: 1
# Word: cornell, Pages List: 1
# Word: ny, Pages List: 13
# Word: pennsylvania, Pages List: 4
# Word: 22, Pages List: 1
# Word: irvine, Pages List: 1
# Word: 23, Pages List: 1
# Word: rutgers, Pages List: 1
# Word: georgia, Pages List: 3
# Word: technology, Pages List: 2
# Word: atlanta, Pages List: 1
# Word: san, Pages List: 5
# Word: diego, Pages List: 2
# Word: 26, Pages List: 1
# Word: columbia, Pages List: 2
# Word: city, Pages List: 3
# Word: duke, Pages List: 1
# Word: nc, Pages List: 1
# Word: 28, Pages List: 1
# Word: tuscon, Pages List: 1
# Word: 29, Pages List: 1
# Word: illinois, Pages List: 5
# Word: chicago, Pages List: 3
# Word: suny, Pages List: 6
# Word: stony, Pages List: 1
# Word: 31, Pages List: 1
# Word: yale, Pages List: 1
# Word: ct, Pages List: 1
# Word: 32, Pages List: 1
# Word: station, Pages List: 1
# Word: 34, Pages List: 1
# Word: davis, Pages List: 1
# Word: 35, Pages List: 1
# Word: boulder, Pages List: 1
# Word: philadelphia, Pages List: 1
# Word: 37, Pages List: 1
# Word: brown, Pages List: 1
# Word: ri, Pages List: 1
# Word: 38, Pages List: 1
# Word: rice, Pages List: 1
# Word: tx, Pages List: 3
# Word: michigan, Pages List: 4
# Word: east, Pages List: 1
# Word: lansing, Pages List: 1
# Word: 40, Pages List: 1
# Word: gainesville, Pages List: 1
# Word: 41, Pages List: 1
# Word: southwestern, Pages List: 1
# Word: lafayette, Pages List: 1
# Word: northwestern, Pages List: 1
# Word: il, Pages List: 2
# Word: 43, Pages List: 1
# Word: 44, Pages List: 1
# Word: johns, Pages List: 1
# Word: hopkins, Pages List: 1
# Word: md, Pages List: 2
# Word: 46, Pages List: 1
# Word: louisiana, Pages List: 2
# Word: baton, Pages List: 1
# Word: rouge, Pages List: 1
# Word: iowa, Pages List: 2
# Word: ames, Pages List: 1
# Word: cruz, Pages List: 1
# Word: 49, Pages List: 1
# Word: richardson, Pages List: 1
# Word: 50, Pages List: 1
# Word: harvard, Pages List: 1
# Word: north, Pages List: 6
# Word: chapel, Pages List: 1
# Word: hill, Pages List: 1
# Word: 52, Pages List: 1
# Word: case, Pages List: 1
# Word: western, Pages List: 4
# Word: reserve, Pages List: 1
# Word: oh, Pages List: 7
# Word: 53, Pages List: 1
# Word: 54, Pages List: 1
# Word: clemson, Pages List: 1
# Word: sc, Pages List: 2
# Word: 55, Pages List: 1
# Word: 56, Pages List: 1
# Word: naval, Pages List: 2
# Word: postgraduate, Pages List: 2
# Word: 57, Pages List: 1
# Word: washington, Pages List: 5
# Word: mo, Pages List: 1
# Word: 58, Pages List: 1
# Word: 59, Pages List: 1
# Word: 60, Pages List: 1
# Word: knoxville, Pages List: 1
# Word: 61, Pages List: 1
# Word: virgina, Pages List: 1
# Word: polytechnic, Pages List: 3
# Word: blacksburg, Pages List: 1
# Word: 62, Pages List: 1
# Word: syracuse, Pages List: 1
# Word: 63, Pages List: 1
# Word: 64, Pages List: 1
# Word: carolina, Pages List: 4
# Word: raleigh, Pages List: 1
# Word: 65, Pages List: 1
# Word: william, Pages List: 1
# Word: va, Pages List: 4
# Word: 66, Pages List: 1
# Word: northeastern, Pages List: 1
# Word: 67, Pages List: 1
# Word: vanderbilt, Pages List: 1
# Word: tn, Pages List: 2
# Word: 68, Pages List: 1
# Word: rensselaer, Pages List: 1
# Word: polytechic, Pages List: 1
# Word: 69, Pages List: 1
# Word: salt, Pages List: 1
# Word: lake, Pages List: 2
# Word: 70, Pages List: 1
# Word: methodist, Pages List: 1
# Word: 71, Pages List: 1
# Word: 72, Pages List: 1
# Word: eugene, Pages List: 1
# Word: 73, Pages List: 1
# Word: george, Pages List: 2
# Word: mason, Pages List: 1
# Word: 74, Pages List: 1
# Word: dominion, Pages List: 1
# Word: 75, Pages List: 1
# Word: pullman, Pages List: 1
# Word: 76, Pages List: 1
# Word: california, Pages List: 6
# Word: pasadena, Pages List: 1
# Word: 77, Pages List: 1
# Word: colorado, Pages List: 2
# Word: fort, Pages List: 1
# Word: collins, Pages List: 1
# Word: 78, Pages List: 1
# Word: 79, Pages List: 1
# Word: 80, Pages List: 1
# Word: jersey, Pages List: 1
# Word: newark, Pages List: 2
# Word: 81, Pages List: 1
# Word: baltimore, Pages List: 3
# Word: 82, Pages List: 1
# Word: rhode, Pages List: 1
# Word: kingston, Pages List: 1
# Word: 83, Pages List: 1
# Word: central, Pages List: 1
# Word: orlando, Pages List: 1
# Word: 84, Pages List: 1
# Word: 85, Pages List: 1
# Word: brigham, Pages List: 1
# Word: young, Pages List: 1
# Word: ut, Pages List: 1
# Word: 86, Pages List: 1
# Word: antonio, Pages List: 1
# Word: 87, Pages List: 1
# Word: riverside, Pages List: 1
# Word: 88, Pages List: 1
# Word: portland, Pages List: 3
# Word: 89, Pages List: 1
# Word: notre, Pages List: 1
# Word: south, Pages List: 4
# Word: 90, Pages List: 1
# Word: oregon, Pages List: 2
# Word: corvallis, Pages List: 1
# Word: 91, Pages List: 1
# Word: wayne, Pages List: 1
# Word: mi, Pages List: 1
# Word: 92, Pages List: 1
# Word: tampa, Pages List: 1
# Word: 93, Pages List: 1
# Word: lexington, Pages List: 1
# Word: 94, Pages List: 1
# Word: 95, Pages List: 1
# Word: stoors, Pages List: 1
# Word: 96, Pages List: 1
# Word: tuscaloosa, Pages List: 1
# Word: 97, Pages List: 1
# Word: wright, Pages List: 1
# Word: 98, Pages List: 1
# Word: miami, Pages List: 2
# Word: 99, Pages List: 1
# Word: brandeis, Pages List: 1
# Word: 100, Pages List: 1
# Word: albuquerque, Pages List: 1
# Word: 101, Pages List: 1
# Word: indiana, Pages List: 4
# Word: bloomington, Pages List: 1
# Word: 102, Pages List: 1
# Word: lincoln, Pages List: 1
# Word: 103, Pages List: 1
# Word: 104, Pages List: 1
# Word: dartmouth, Pages List: 1
# Word: nh, Pages List: 1
# Word: 105, Pages List: 1
# Word: burlington, Pages List: 1
# Word: 106, Pages List: 1
# Word: stevens, Pages List: 1
# Word: 107, Pages List: 1
# Word: hawai, Pages List: 1
# Word: manoa, Pages List: 1
# Word: 108, Pages List: 1
# Word: 109, Pages List: 1
# Word: kent, Pages List: 1
# Word: 110, Pages List: 1
# Word: 111, Pages List: 1
# Word: kansas, Pages List: 2
# Word: 112, Pages List: 1
# Word: wichita, Pages List: 1
# Word: 113, Pages List: 1
# Word: arizona, Pages List: 1
# Word: 114, Pages List: 1
# Word: air, Pages List: 1
# Word: force, Pages List: 1
# Word: 115, Pages List: 1
# Word: drexel, Pages List: 1
# Word: 116, Pages List: 1
# Word: worcester, Pages List: 1
# Word: 117, Pages List: 1
# Word: arlington, Pages List: 1
# Word: 118, Pages List: 1
# Word: 119, Pages List: 1
# Word: mississipi, Pages List: 1
# Word: 120, Pages List: 1
# Word: carbonale, Pages List: 1
# Word: 121, Pages List: 1
# Word: auburn, Pages List: 1
# Word: al, Pages List: 1
# Word: 122, Pages List: 1
# Word: wyoming, Pages List: 1
# Word: 123, Pages List: 1
# Word: 124, Pages List: 1
# Word: florida, Pages List: 6
# Word: atlantic, Pages List: 2
# Word: 125, Pages List: 1
# Word: laval, Pages List: 1
# Word: 126, Pages List: 1
# Word: cuny, Pages List: 3
# Word: 127, Pages List: 1
# Word: arkansas, Pages List: 1
# Word: 128, Pages List: 1
# Word: 129, Pages List: 1
# Word: dalhousie, Pages List: 1
# Word: 130, Pages List: 1
# Word: waikato, Pages List: 1
# Word: 131, Pages List: 1
# Word: 132, Pages List: 1
# Word: northern, Pages List: 2
# Word: 133, Pages List: 1
# Word: smith, Pages List: 1
# Word: massachusetts, Pages List: 1
# Word: 134, Pages List: 1
# Word: loyola, Pages List: 2
# Word: 135, Pages List: 1
# Word: denver, Pages List: 2
# Word: 136, Pages List: 1
# Word: 137, Pages List: 1
# Word: wesleyan, Pages List: 1
# Word: connecticut, Pages List: 4
# Word: 138, Pages List: 1
# Word: mexico, Pages List: 2
# Word: 139, Pages List: 1
# Word: 140, Pages List: 1
# Word: fairbanks, Pages List: 1
# Word: 141, Pages List: 1
# Word: virginia, Pages List: 3
# Word: 142, Pages List: 1
# Word: 143, Pages List: 1
# Word: research, Pages List: 1
# Word: learning, Pages List: 1
# Word: 144, Pages List: 1
# Word: mississippi, Pages List: 1
# Word: 145, Pages List: 1
# Word: el, Pages List: 1
# Word: paso, Pages List: 1
# Word: 146, Pages List: 1
# Word: las, Pages List: 1
# Word: vegas, Pages List: 1
# Word: 147, Pages List: 1
# Word: claremont, Pages List: 1
# Word: graduate, Pages List: 1
# Word: usa, Pages List: 15
# Word: 148, Pages List: 1
# Word: jose, Pages List: 1
# Word: 149, Pages List: 1
# Word: technological, Pages List: 1
# Word: 150, Pages List: 1
# Word: alabama, Pages List: 3
# Word: birmingham, Pages List: 1
# Word: 151, Pages List: 1
# Word: 152, Pages List: 1
# Word: 153, Pages List: 1
# Word: tulane, Pages List: 1
# Word: 154, Pages List: 1
# Word: 155, Pages List: 1
# Word: hampton, Pages List: 1
# Word: 156, Pages List: 1
# Word: 157, Pages List: 1
# Word: rochester, Pages List: 1
# Word: 158, Pages List: 1
# Word: flushing, Pages List: 1
# Word: 159, Pages List: 1
# Word: edinboro, Pages List: 1
# Word: 160, Pages List: 1
# Word: iona, Pages List: 1
# Word: 161, Pages List: 1
# Word: athens, Pages List: 1
# Word: 162, Pages List: 1
# Word: 163, Pages List: 1
# Word: national, Pages List: 2
# Word: institutes, Pages List: 1
# Word: 164, Pages List: 1
# Word: davidson, Pages List: 1
# Word: 165, Pages List: 1
# Word: edwardsw, Pages List: 1
# Word: 166, Pages List: 1
# Word: 167, Pages List: 1
# Word: maths, Pages List: 1
# Word: minneso, Pages List: 1
# Word: 168, Pages List: 1
# Word: charlotte, Pages List: 1
# Word: 169, Pages List: 1
# Word: 170, Pages List: 1
# Word: 171, Pages List: 1
# Word: defense, Pages List: 1
# Word: dc, Pages List: 1
# Word: 172, Pages List: 1
# Word: glassboro, Pages List: 1
# Word: 173, Pages List: 1
# Word: royal, Pages List: 1
# Word: military, Pages List: 2
# Word: science, Pages List: 1
# Word: 174, Pages List: 1
# Word: union, Pages List: 1
# Word: 175, Pages List: 1
# Word: sweden, Pages List: 1
# Word: 176, Pages List: 1
# Word: suffolk, Pages List: 1
# Word: 177, Pages List: 1
# Word: maine, Pages List: 1
# Word: 178, Pages List: 1
# Word: 179, Pages List: 1
# Word: 180, Pages List: 1
# Word: williams, Pages List: 1
# Word: 181, Pages List: 1
# Word: temple, Pages List: 1
# Word: 182, Pages List: 1
# Word: montclair, Pages List: 1
# Word: 183, Pages List: 1
# Word: queens, Pages List: 1
# Word: 184, Pages List: 1
# Word: pacific, Pages List: 1
# Word: lutheran, Pages List: 1
# Word: 185, Pages List: 1
# Word: butler, Pages List: 1
# Word: 186, Pages List: 1
# Word: marymount, Pages List: 1
# Word: 187, Pages List: 1
# Word: colegio, Pages List: 1
# Word: de, Pages List: 1
# Word: postgraduados, Pages List: 1
# Word: 188, Pages List: 1
# Word: 189, Pages List: 1
# Word: georgetown, Pages List: 1
# Word: 190, Pages List: 1
# Word: minnesota, Pages List: 1
# Word: 191, Pages List: 1
# Word: 192, Pages List: 1
# Word: 193, Pages List: 1
# Word: fullerton, Pages List: 2
# Word: 194, Pages List: 1
# Word: brooklyn, Pages List: 1
# Word: 195, Pages List: 1
# Word: bowling, Pages List: 1
# Word: green, Pages List: 1
# Word: 196, Pages List: 1
# Word: youngstown, Pages List: 1
# Word: 197, Pages List: 1
# Word: ande, Pages List: 1
# Word: cancer, Pages List: 1
# Word: cen, Pages List: 1
# Word: 198, Pages List: 1
# Word: 199, Pages List: 1
# Word: unc, Pages List: 1
# Word: greensboro, Pages List: 1
# Word: 200, Pages List: 1
# Word: emory, Pages List: 1
# Word: ga, Pages List: 1
# Word: 201, Pages List: 1
# Word: toledo, Pages List: 1
# Word: 202, Pages List: 1
# Word: humboldt, Pages List: 1
# Word: 203, Pages List: 1
# Word: hayward, Pages List: 1
# Word: 204, Pages List: 1
# Word: muskingum, Pages List: 1
# Word: 205, Pages List: 1
# Word: 206, Pages List: 1
# Word: southwest, Pages List: 1
# Word: 207, Pages List: 1
# Word: maryville, Pages List: 1
# Word: tennessee, Pages List: 2
# Word: 208, Pages List: 1
# Word: 209, Pages List: 1
# Word: 210, Pages List: 1
# Word: bentley, Pages List: 1
# Word: 211, Pages List: 1
# Word: united, Pages List: 1
# Word: states, Pages List: 1
# Word: academy, Pages List: 1
# Word: 212, Pages List: 1
# Word: wilkes, Pages List: 1
# Word: 213, Pages List: 1
# Word: 214, Pages List: 1
# Word: 215, Pages List: 1
# Word: space, Pages List: 2
# Word: 216, Pages List: 1
# Word: 217, Pages List: 1
# Word: barnard, Pages List: 1
# Word: baruch, Pages List: 1
# Word: 218, Pages List: 1
# Word: christopher, Pages List: 1
# Word: newport, Pages List: 1
# Word: 219, Pages List: 1
# Word: lecce, Pages List: 1
# Word: 220, Pages List: 1
# Word: clarkson, Pages List: 1
# Word: 221, Pages List: 1
# Word: duluth, Pages List: 1
# Word: 222, Pages List: 1
# Word: 223, Pages List: 1
# Word: 224, Pages List: 1
# Word: district, Pages List: 1
# Word: 225, Pages List: 1
# Word: orleans, Pages List: 1
# Word: 226, Pages List: 1
# Word: lehigh, Pages List: 1
# Word: 227, Pages List: 1
# Word: mn, Pages List: 1
# Word: 228, Pages List: 1
# Word: 229, Pages List: 1
# Word: emporia, Pages List: 1
# Word: ks, Pages List: 1
# Word: 230, Pages List: 1
# Word: francisco, Pages List: 1
# Word: 231, Pages List: 1
# Word: hunter, Pages List: 1
# Word: 232, Pages List: 1
# Word: school, Pages List: 1
# Word: mines, Pages List: 1
# Word: 233, Pages List: 1
# Word: carson, Pages List: 1
# Word: 234, Pages List: 1
# Word: saint, Pages List: 1
# Word: 235, Pages List: 1
# Word: cloud, Pages List: 1
# Word: 236, Pages List: 1
# Word: moorpark, Pages List: 1
# Word: 237, Pages List: 1
# Word: staten, Pages List: 1
# Word: 238, Pages List: 1
# Word: memphis, Pages List: 1
# Word: 239, Pages List: 1
# Word: international, Pages List: 1
# Word: 240, Pages List: 1
# Word: tech, Pages List: 1
# Word: 241, Pages List: 1
# Word: 242, Pages List: 1
# Word: oshkosh, Pages List: 1
# Word: 243, Pages List: 1
# Word: paltz, Pages List: 1
# Word: 244, Pages List: 1
# Word: melbour, Pages List: 1
# Word: 245, Pages List: 1
# Word: dakota, Pages List: 1
# Word: 246, Pages List: 1
# Word: 247, Pages List: 1
# Word: centre, Pages List: 1
# Word: kentucky, Pages List: 1
# Word: 248, Pages List: 1
# Word: 249, Pages List: 1
# Word: baylor, Pages List: 1
# Word: 250, Pages List: 1
# Word: 251, Pages List: 1
# Word: depaul, Pages List: 1
# Word: 252, Pages List: 1
# Word: 253, Pages List: 1
# Word: rolla, Pages List: 1
# Word: 254, Pages List: 1
# Word: 255, Pages List: 1
# Word: willamette, Pages List: 1
# Word: 256, Pages List: 1
# Word: res, Pages List: 1
# Word: inst, Pages List: 1
# Word: adv, Pages List: 1
# Word: comp, Pages List: 1
# Word: 257, Pages List: 1
# Word: bell, Pages List: 1
# Word: 258, Pages List: 1
# Word: la, Pages List: 2
# Word: jolla, Pages List: 1
# Word: 259, Pages List: 1
# Word: eau, Pages List: 1
# Word: clare, Pages List: 1
# Word: 260, Pages List: 1
# Word: cleveland, Pages List: 1
# Word: 261, Pages List: 1
# Word: 262, Pages List: 1
# Word: michelson, Pages List: 1
# Word: 263, Pages List: 1
# Word: towson, Pages List: 1
# Word: 264, Pages List: 1
# Word: denton, Pages List: 1
# Word: 265, Pages List: 1
# Word: eastern, Pages List: 1
# Word: 266, Pages List: 1
# Word: clara, Pages List: 1
# Word: 267, Pages List: 1
# Word: lycoming, Pages List: 1
# Word: 268, Pages List: 1
# Word: macalester, Pages List: 1
# Word: 269, Pages List: 1
# Word: 270, Pages List: 1
# Word: 271, Pages List: 1
# Word: helsinki, Pages List: 1
# Word: finland, Pages List: 1
# Word: 272, Pages List: 1
# Word: clark, Pages List: 1
# Word: 273, Pages List: 1
# Word: 274, Pages List: 1
# Word: wier, Pages List: 1
# Word: 275, Pages List: 1
# Word: 276, Pages List: 1
# Word: randolph, Pages List: 1
# Word: macon, Pages List: 1
# Word: 277, Pages List: 1
# Word: 278, Pages List: 1
# Word: rockefeller, Pages List: 1
# Word: 279, Pages List: 1
# Word: brock, Pages List: 1
# Word: 280, Pages List: 1
# Word: clear, Pages List: 1
# Word: 281, Pages List: 1
# Word: christian, Pages List: 1
# Word: 282, Pages List: 1
# Word: univ, Pages List: 1
# Word: indianapolis, Pages List: 1
# Word: 283, Pages List: 1
# Word: telescope, Pages List: 1
# Word: 284, Pages List: 1
# Word: oberlin, Pages List: 1
# Word: 285, Pages List: 1
# Word: harvey, Pages List: 1
# Word: mudd, Pages List: 1
# Word: 286, Pages List: 1
# Word: huntsville, Pages List: 1
# Word: 287, Pages List: 1
# Word: 288, Pages List: 1
# Word: westminister, Pages List: 1
# Word: 289, Pages List: 1
# Word: 290, Pages List: 1
# Word: barry, Pages List: 1
#
# Relevant Page IDs for Query: []
# Best Fitness Value: 0.9817000533762049

# %%
import os
import re
import random
import numpy as np

# Function to extract page ID from the filename
def get_page_id(file_name):
    match = re.search(r'page(\d+)', file_name)
    if match:
        return int(match.group(1))
    else:
        return None

# Function to extract page name from the filename
def get_page_name(file_name):
    # Extract page name from the filename by removing the file extension
    return os.path.splitext(file_name)[0]

# Function to preprocess the document content
def preprocess_document(document_content):
    # Tokenize the content by splitting on spaces (you can use more advanced tokenization)
    words = document_content.split()

    # Remove stop words, special characters, and sentence delimiters
    stop_words = set(["the", "and", "is", "in", "it", "an", "to", "of", "as", "by"])
    words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

    # Calculate total weight (word count) and total count word
    total_weight = len(words)
    total_count_word = len(set(words))

    return total_weight, total_count_word, words

# Function to perform document indexing
def document_indexing(dataset_path):
    pages_information = {}
    words_information = {}

    for root, _, files in os.walk(dataset_path):
        for file_name in files:
            if file_name.endswith(".txt"):
                with open(os.path.join(root, file_name), 'r', encoding='utf-8') as file:
                    document_content = file.read()
                    total_weight, total_count_word, words = preprocess_document(document_content)

                    page_id = get_page_id(file_name)
                    page_name = get_page_name(file_name)

                    # Store page information
                    pages_information[page_id] = {
                        "page_name": page_name,
                        "total_weight": total_weight,
                        "total_count_word": total_count_word,
                    }

                    # Update words information
                    for word in words:
                        if word not in words_information:
                            words_information[word] = {"pages_list": [page_id]}
                        else:
                            words_information[word]["pages_list"].append(page_id)

    return pages_information, words_information

# Function to perform query search
def query_search(user_query, words_information):
    query_words = user_query.lower().split()
    id_list = []

    for word in query_words:
        if word in words_information:
            id_list.extend(words_information[word]["pages_list"])
        else:
            print(f"Word '{word}' not found in indexed words.")

    return list(set(id_list))  # Remove duplicates


# Function to perform the modified GA procedure
def modified_genetic_algorithm(population_size, num_iterations):
    # Replace this with your actual genetic algorithm logic
    # Here, we'll just generate random fitness values for demonstration
    fitness_values = [random.random() for _ in range(population_size)]

    # Return the best fitness value after the specified number of iterations
    best_fitness = max(fitness_values)
    return best_fitness

# Function to print words information in a table format
def print_words_information(words_information):
    print("\nWords Information:")
    print("{:<20} {}".format("Word", "Page IDs"))

    for word, info in words_information.items():
        page_ids = ', '.join(map(str, info["pages_list"]))
        print("{:<20} {}".format(word, page_ids))

if __name__ == "__main__":
    dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"

    # Algorithm 1: Document Indexing
    pages_information, words_information = document_indexing(dataset_path)

    # Algorithm 2: Query Search
    user_query = "ANALYSIS CRYPTOGRAPHIC PROTOCOLS"
    relevant_page_ids = query_search(user_query, words_information)

    # Algorithm 3: Modified Genetic Algorithm
    population_size = 50
    num_iterations = 20
    best_fitness = modified_genetic_algorithm(population_size, num_iterations)

    # Print results
    print("Pages Information:")
    for page_id, page_info in pages_information.items():
        print(f"Page ID: {page_id}, Page Name: {page_info['page_name']}, Total Weight: {page_info['total_weight']}, Total Count Word: {page_info['total_count_word']}")

    print_words_information(words_information)

    print("\nRelevant Page IDs for Query:", relevant_page_ids)
    print("Best Fitness Value:", best_fitness)
# Out:
# Word 'analysis' not found in indexed words.
# Word 'cryptographic' not found in indexed words.
# Word 'protocols' not found in indexed words.
# Pages Information:
# Page ID: None, Page Name: http_^^www.cs.clemson.edu^~madhu^usa, Total Weight: 1085, Total Count Word: 649
#
# Words Information:
# Word                 Page IDs
# 14                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# jan                  None, None, None, None, None, None, None
# 1997                 None, None, None, None, None, None, None
# gmt                  None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 15                   None, None, None, None, None, None, None, None, None, None, None, None
# feb                  None
# 1996                 None, None, None
# 3082                 None
# problem              None, None, None, None, None
# 1                    None, None, None, None, None, None, None, None, None, None, None, None
# part                 None, None, None, None, None, None, None, None
# a                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# though               None, None
# not                  None, None, None, None, None
# for                  None, None, None, None, None, None, None, None, None, None, None, None
# longer               None
# but                  None, None, None, None, None, None, None
# was                  None
# b                    None, None
# grandparent          None
# parent               None, None, None, None, None, None
# x                    None, None, None, None, None, None, None
# mother               None, None
# y                    None, None, None
# if                   None, None, None, None, None, None, None
# female               None
# sibling              None, None
# different            None
# person               None, None, None, None
# with                 None, None, None, None, None, None, None
# same                 None, None
# sister               None, None
# law                  None, None
# either               None, None, None
# or                   None, None, None, None, None, None, None
# wife                 None, None
# c                    None
# that                 None, None, None
# this                 None, None, None
# often                None
# go                   None
# into                 None
# infinite             None
# you                  None, None, None
# ask                  None, None, None
# query                None
# whose                None
# answer               None, None, None
# should               None
# be                   None, None, None, None, None, None, None
# find                 None, None
# spouse               None, None
# unmarried            None
# who                  None
# will                 None
# return               None, None
# infinitely           None
# many                 None, None
# times                None
# on                   None, None, None, None, None, None, None, None
# diana                None, None, None
# requesting           None, None
# another              None, None, None
# use                  None
# auxiliary            None
# predicate            None
# state                None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# fact                 None
# once                 None, None, None
# each                 None, None, None
# then                 None, None
# define               None
# terms                None
# 2                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# run                  None
# backwards            None
# split                None
# last                 None, None, None, None, None
# element              None, None, None
# from                 None, None, None, None
# rest                 None
# them                 None
# connected            None, None
# other                None, None, None, None, None
# more                 None, None, None
# straightforward      None
# take                 None, None, None
# off                  None, None
# all                  None, None, None, None
# reconnect            None
# binds                None, None, None
# r                    None, None
# rotates              None
# succeeds             None
# applies              None
# k                    None, None, None
# rotations            None
# returning            None
# k1                   None
# m                    None, None, None, None
# rotation             None
# l                    None, None
# keeps                None
# rotating             None
# backtrackings        None
# are                  None, None, None, None, None, None
# 4                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# n                    None, None
# n1                   None
# e                    None
# 522                  None
# 08                   None
# 2578                 None
# atomic               None, None
# transaction          None, None, None, None, None, None, None
# like                 None
# signing              None
# contract             None
# two                  None, None
# they                 None
# both                 None, None, None
# fig                  None, None, None, None, None, None, None
# withdraw             None
# my                   None
# deposit              None
# your                 None
# model                None
# independent          None
# which                None, None, None, None, None, None
# can                  None, None, None, None, None
# fail                 None
# at                   None, None, None, None, None, None, None, None, None, None, None, None, None
# random               None
# communication        None
# reliable             None
# timeout              None
# stable               None, None, None
# storage              None, None, None, None
# 3                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# types                None
# ram                  None
# power                None
# machine              None
# crashes              None, None
# disk                 None, None
# survives             None
# cpu                  None
# failures             None, None
# lost                 None
# head                 None
# designed             None, None, None
# survive              None
# any                  None, None
# primitive            None
# start                None
# terminate            None
# commit               None, None, None, None, None, None, None
# kill                 None
# restore              None
# old                  None, None, None
# value                None
# read                 None
# write                None, None
# properties           None
# transactions         None, None, None, None
# indivisible          None
# outside              None
# maintain             None
# system               None, None, None, None
# invariants           None
# no                   None, None, None
# interference         None
# concurrent           None, None, None
# committed            None, None
# changes              None, None
# permanent            None
# append               None
# file                 None, None
# consistent           None, None
# conservation         None
# money                None
# isolated             None
# serializable         None
# serial               None
# serialized           None
# ok                   None, None
# since                None
# values               None, None
# illegal              None
# nested               None
# may                  None
# execute              None
# one                  None, None
# subtransactions      None
# when                 None, None, None
# subtransaction       None, None
# its                  None, None
# results              None, None
# visible              None
# must                 None
# implementation       None
# how                  None, None, None
# undo                 None
# intermediate         None
# updates              None
# private              None, None
# workspace            None, None
# give                 None
# copy                 None
# needed               None
# writeahead           None
# log                  None, None, None, None
# intentions           None
# files                None, None
# actually             None
# modified             None
# place                None
# before               None, None
# record               None, None
# written              None, None
# new                  None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# after                None
# changed              None
# undone               None
# also                 None, None, None
# used                 None, None
# recovering           None
# protocol             None, None, None
# atomically           None
# why                  None
# general              None
# paradox              None
# generals             None
# want                 None
# agree                None, None
# time                 None
# even                 None
# some                 None
# messengers           None
# do                   None
# get                  None
# impossibility        None
# assume               None
# exist                None
# shortest             None
# sequence             None
# msgs                 None, None
# goal                 None
# sites                None
# abort                None
# relax                None
# req                  None
# number               None, None
# bounded              None
# fixed                None
# 337                  None
# 18                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# dec                  None, None
# 6459                 None
# column               None
# heading              None
# means                None
# assignment           None
# worth                None
# total                None, None
# points               None, None
# extra                None, None
# hmwk1                None
# hmwk2                None
# hmwk3                None
# hmwk4                None
# mid                  None
# hmwk5                None
# hmwk6                None
# hmwk7                None
# hmwk8                None
# hmwk9                None
# final                None
# 7                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 39                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 51                   None, None
# 5                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 8                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 21                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 6                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 27                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 9                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 11                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 33                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 13                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 45                   None, None, None, None, None, None, None
# 10                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 12                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 36                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 24                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 30                   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 42                   None, None, None, None, None, None, None, None, None, None
# 0                    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 48                   None, None
# 47                   None, None
# 1396                 None
# sep                  None
# name                 None, None
# username             None
# known                None
# address              None
# blau                 None
# seth                 None
# d                    None, None
# sdb5200              None
# carr                 None
# richard              None
# rrc8372              None
# diament              None
# judah                None
# michael              None, None
# jmd205               None
# elkin                None
# vadim                None
# ve201                None
# fuh                  None
# paul                 None
# pqf3581              None
# hanna                None
# adel                 None
# ah1                  None
# hertzmann            None
# aaron                None
# phillip              None
# aph201               None
# huggins              None
# patrick              None
# s                    None
# psh9057              None
# jawalekar            None
# raju                 None
# v                    None, None, None, None, None
# rvj1                 None
# jermyn               None
# ian                  None
# hyla                 None
# ihj200               None
# kim                  None
# jae                  None
# hwan                 None
# jhk5364              None
# llaurado             None
# ramon                None
# rql6719              None
# newman               None
# joshua               None
# amiel                None
# jqn0794              None
# pao                  None
# hkp1                 None
# raskin               None
# gabriel              None
# carl                 None
# gcr3340              None
# sceniak              None
# p                    None, None
# mps1707              None
# singer               None
# eric                 None
# lee                  None
# els3339              None
# wu                   None
# xiangyang            None
# xqw5048              None
# 09                   None
# 1994                 None
# 2709                 None
# user                 None
# commands             None
# arthur               None, None, None, None, None, None
# intelligence         None
# language             None
# process              None, None, None, None
# tactile              None
# audible              None
# express              None
# purpose              None
# interacting          None
# synopsis             None, None
# play                 None, None
# availability         None
# version              None
# command              None
# available            None
# tem                  None
# software             None
# installation         None
# refer                None
# installing           None
# sunos                None
# information          None
# install              None
# invoke               None
# description          None
# invoked              None
# four                 None
# major                None
# involves             None
# output               None
# depends              None
# complicated          None
# way                  None, None
# sensory              None
# options              None
# option               None, None, None, None
# allows               None
# dormant              None
# period               None
# temporarily          None
# suspends             None
# processes            None
# food                 None
# specify              None
# calories             None
# color                None
# q                    None
# operating            None
# wide                 None
# ranging              None
# field                None
# examples             None
# include              None
# early                None
# morning              None
# programming          None
# sessions             None
# porch                None
# portable             None
# late                 None
# night                None
# doodling             None
# unreadable           None
# mix                  None
# print                None
# script               None
# ubiquitous           None
# spiral               None
# bound                None
# college              None, None, None, None, None, None, None
# recently             None
# installed            None
# significantly        None
# upgraded             None
# now                  None
# forevermore          None
# includes             None
# pipe                 None
# result               None
# successful           None
# execution            None
# happiness            None
# bugs                 None
# initiated            None
# given                None
# there                None
# easy                 None
# transfer             None
# operations           None
# especially           None
# true                 None
# reading              None
# considered           None
# work                 None
# unusual              None
# propensity           None
# think                None
# things               None
# believes             None
# logical              None
# thought              None
# utilized             None
# most                 None
# quite                None
# frustrating          None
# blind                None
# truth                None
# tends                None
# ignore               None
# input                None
# specifically         None
# current              None
# yields               None
# high                 None
# level                None
# see                  None
# implementations      None, None
# best                 None
# our                  None
# sun                  None
# release              None
# just                 None
# bennett              None, None
# professor            None
# goldberg             None
# boston               None, None, None, None, None
# university           None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# physics              None
# department           None
# 590                  None
# commonwealth         None, None
# avenue               None
# ma                   None, None, None, None, None, None, None, None, None, None
# 02215                None
# 23471                None
# 25                   None, None
# aug                  None
# 1995                 None
# ranking              None
# us                   None, None
# educational          None
# institutions         None
# massachussets        None
# institute            None, None, None, None, None, None, None, None, None, None, None, None, None, None
# cambridge            None
# park                 None, None
# stanford             None
# palo                 None
# ca                   None, None, None, None, None, None
# carnegie             None
# mellon               None
# pa                   None, None, None, None, None, None, None
# texas                None, None, None, None, None, None, None, None, None
# austin               None
# ann                  None
# arbor                None
# southern             None, None, None, None, None, None
# los                  None, None
# angeles              None, None
# purdue               None
# west                 None, None, None
# berkeley             None
# amherst              None, None
# princeton            None
# nj                   None, None, None, None, None
# seattle              None
# 16                   None
# ohio                 None, None, None, None
# columbus             None
# 17                   None
# york                 None, None, None, None, None, None, None, None
# santa                None, None, None
# barbara              None
# 19                   None
# minneapolis          None, None
# 20                   None
# cornell              None
# ny                   None, None, None, None, None, None, None, None, None, None, None, None, None
# pennsylvania         None, None, None, None
# 22                   None
# irvine               None
# 23                   None
# rutgers              None
# georgia              None, None, None
# technology           None, None
# atlanta              None
# san                  None, None, None, None, None
# diego                None, None
# 26                   None
# columbia             None, None
# city                 None, None, None
# duke                 None
# nc                   None
# 28                   None
# tuscon               None
# 29                   None
# illinois             None, None, None, None, None
# chicago              None, None, None
# suny                 None, None, None, None, None, None
# stony                None
# 31                   None
# yale                 None
# ct                   None
# 32                   None
# station              None
# 34                   None
# davis                None
# 35                   None
# boulder              None
# philadelphia         None
# 37                   None
# brown                None
# ri                   None
# 38                   None
# rice                 None
# tx                   None, None, None
# michigan             None, None, None, None
# east                 None
# lansing              None
# 40                   None
# gainesville          None
# 41                   None
# southwestern         None
# lafayette            None
# northwestern         None
# il                   None, None
# 43                   None
# 44                   None
# johns                None
# hopkins              None
# md                   None, None
# 46                   None
# louisiana            None, None
# baton                None
# rouge                None
# iowa                 None, None
# ames                 None
# cruz                 None
# 49                   None
# richardson           None
# 50                   None
# harvard              None
# north                None, None, None, None, None, None
# chapel               None
# hill                 None
# 52                   None
# case                 None
# western              None, None, None, None
# reserve              None
# oh                   None, None, None, None, None, None, None
# 53                   None
# 54                   None
# clemson              None
# sc                   None, None
# 55                   None
# 56                   None
# naval                None, None
# postgraduate         None, None
# 57                   None
# washington           None, None, None, None, None
# mo                   None
# 58                   None
# 59                   None
# 60                   None
# knoxville            None
# 61                   None
# virgina              None
# polytechnic          None, None, None
# blacksburg           None
# 62                   None
# syracuse             None
# 63                   None
# 64                   None
# carolina             None, None, None, None
# raleigh              None
# 65                   None
# william              None
# va                   None, None, None, None
# 66                   None
# northeastern         None
# 67                   None
# vanderbilt           None
# tn                   None, None
# 68                   None
# rensselaer           None
# polytechic           None
# 69                   None
# salt                 None
# lake                 None, None
# 70                   None
# methodist            None
# 71                   None
# 72                   None
# eugene               None
# 73                   None
# george               None, None
# mason                None
# 74                   None
# dominion             None
# 75                   None
# pullman              None
# 76                   None
# california           None, None, None, None, None, None
# pasadena             None
# 77                   None
# colorado             None, None
# fort                 None
# collins              None
# 78                   None
# 79                   None
# 80                   None
# jersey               None
# newark               None, None
# 81                   None
# baltimore            None, None, None
# 82                   None
# rhode                None
# kingston             None
# 83                   None
# central              None
# orlando              None
# 84                   None
# 85                   None
# brigham              None
# young                None
# ut                   None
# 86                   None
# antonio              None
# 87                   None
# riverside            None
# 88                   None
# portland             None, None, None
# 89                   None
# notre                None
# south                None, None, None, None
# 90                   None
# oregon               None, None
# corvallis            None
# 91                   None
# wayne                None
# mi                   None
# 92                   None
# tampa                None
# 93                   None
# lexington            None
# 94                   None
# 95                   None
# stoors               None
# 96                   None
# tuscaloosa           None
# 97                   None
# wright               None
# 98                   None
# miami                None, None
# 99                   None
# brandeis             None
# 100                  None
# albuquerque          None
# 101                  None
# indiana              None, None, None, None
# bloomington          None
# 102                  None
# lincoln              None
# 103                  None
# 104                  None
# dartmouth            None
# nh                   None
# 105                  None
# burlington           None
# 106                  None
# stevens              None
# 107                  None
# hawai                None
# manoa                None
# 108                  None
# 109                  None
# kent                 None
# 110                  None
# 111                  None
# kansas               None, None
# 112                  None
# wichita              None
# 113                  None
# arizona              None
# 114                  None
# air                  None
# force                None
# 115                  None
# drexel               None
# 116                  None
# worcester            None
# 117                  None
# arlington            None
# 118                  None
# 119                  None
# mississipi           None
# 120                  None
# carbonale            None
# 121                  None
# auburn               None
# al                   None
# 122                  None
# wyoming              None
# 123                  None
# 124                  None
# florida              None, None, None, None, None, None
# atlantic             None, None
# 125                  None
# laval                None
# 126                  None
# cuny                 None, None, None
# 127                  None
# arkansas             None
# 128                  None
# 129                  None
# dalhousie            None
# 130                  None
# waikato              None
# 131                  None
# 132                  None
# northern             None, None
# 133                  None
# smith                None
# massachusetts        None
# 134                  None
# loyola               None, None
# 135                  None
# denver               None, None
# 136                  None
# 137                  None
# wesleyan             None
# connecticut          None, None, None, None
# 138                  None
# mexico               None, None
# 139                  None
# 140                  None
# fairbanks            None
# 141                  None
# virginia             None, None, None
# 142                  None
# 143                  None
# research             None
# learning             None
# 144                  None
# mississippi          None
# 145                  None
# el                   None
# paso                 None
# 146                  None
# las                  None
# vegas                None
# 147                  None
# claremont            None
# graduate             None
# usa                  None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
# 148                  None
# jose                 None
# 149                  None
# technological        None
# 150                  None
# alabama              None, None, None
# birmingham           None
# 151                  None
# 152                  None
# 153                  None
# tulane               None
# 154                  None
# 155                  None
# hampton              None
# 156                  None
# 157                  None
# rochester            None
# 158                  None
# flushing             None
# 159                  None
# edinboro             None
# 160                  None
# iona                 None
# 161                  None
# athens               None
# 162                  None
# 163                  None
# national             None, None
# institutes           None
# 164                  None
# davidson             None
# 165                  None
# edwardsw             None
# 166                  None
# 167                  None
# maths                None
# minneso              None
# 168                  None
# charlotte            None
# 169                  None
# 170                  None
# 171                  None
# defense              None
# dc                   None
# 172                  None
# glassboro            None
# 173                  None
# royal                None
# military             None, None
# science              None
# 174                  None
# union                None
# 175                  None
# sweden               None
# 176                  None
# suffolk              None
# 177                  None
# maine                None
# 178                  None
# 179                  None
# 180                  None
# williams             None
# 181                  None
# temple               None
# 182                  None
# montclair            None
# 183                  None
# queens               None
# 184                  None
# pacific              None
# lutheran             None
# 185                  None
# butler               None
# 186                  None
# marymount            None
# 187                  None
# colegio              None
# de                   None
# postgraduados        None
# 188                  None
# 189                  None
# georgetown           None
# 190                  None
# minnesota            None
# 191                  None
# 192                  None
# 193                  None
# fullerton            None, None
# 194                  None
# brooklyn             None
# 195                  None
# bowling              None
# green                None
# 196                  None
# youngstown           None
# 197                  None
# ande                 None
# cancer               None
# cen                  None
# 198                  None
# 199                  None
# unc                  None
# greensboro           None
# 200                  None
# emory                None
# ga                   None
# 201                  None
# toledo               None
# 202                  None
# humboldt             None
# 203                  None
# hayward              None
# 204                  None
# muskingum            None
# 205                  None
# 206                  None
# southwest            None
# 207                  None
# maryville            None
# tennessee            None, None
# 208                  None
# 209                  None
# 210                  None
# bentley              None
# 211                  None
# united               None
# states               None
# academy              None
# 212                  None
# wilkes               None
# 213                  None
# 214                  None
# 215                  None
# space                None, None
# 216                  None
# 217                  None
# barnard              None
# baruch               None
# 218                  None
# christopher          None
# newport              None
# 219                  None
# lecce                None
# 220                  None
# clarkson             None
# 221                  None
# duluth               None
# 222                  None
# 223                  None
# 224                  None
# district             None
# 225                  None
# orleans              None
# 226                  None
# lehigh               None
# 227                  None
# mn                   None
# 228                  None
# 229                  None
# emporia              None
# ks                   None
# 230                  None
# francisco            None
# 231                  None
# hunter               None
# 232                  None
# school               None
# mines                None
# 233                  None
# carson               None
# 234                  None
# saint                None
# 235                  None
# cloud                None
# 236                  None
# moorpark             None
# 237                  None
# staten               None
# 238                  None
# memphis              None
# 239                  None
# international        None
# 240                  None
# tech                 None
# 241                  None
# 242                  None
# oshkosh              None
# 243                  None
# paltz                None
# 244                  None
# melbour              None
# 245                  None
# dakota               None
# 246                  None
# 247                  None
# centre               None
# kentucky             None
# 248                  None
# 249                  None
# baylor               None
# 250                  None
# 251                  None
# depaul               None
# 252                  None
# 253                  None
# rolla                None
# 254                  None
# 255                  None
# willamette           None
# 256                  None
# res                  None
# inst                 None
# adv                  None
# comp                 None
# 257                  None
# bell                 None
# 258                  None
# la                   None, None
# jolla                None
# 259                  None
# eau                  None
# clare                None
# 260                  None
# cleveland            None
# 261                  None
# 262                  None
# michelson            None
# 263                  None
# towson               None
# 264                  None
# denton               None
# 265                  None
# eastern              None
# 266                  None
# clara                None
# 267                  None
# lycoming             None
# 268                  None
# macalester           None
# 269                  None
# 270                  None
# 271                  None
# helsinki             None
# finland              None
# 272                  None
# clark                None
# 273                  None
# 274                  None
# wier                 None
# 275                  None
# 276                  None
# randolph             None
# macon                None
# 277                  None
# 278                  None
# rockefeller          None
# 279                  None
# brock                None
# 280                  None
# clear                None
# 281                  None
# christian            None
# 282                  None
# univ                 None
# indianapolis         None
# 283                  None
# telescope            None
# 284                  None
# oberlin              None
# 285                  None
# harvey               None
# mudd                 None
# 286                  None
# huntsville           None
# 287                  None
# 288                  None
# westminister         None
# 289                  None
# 290                  None
# barry                None
#
# Relevant Page IDs for Query: []
# Best Fitness Value: 0.9389838039792

# %%
import random

# Data Structures
pages_information = {}  # Dictionary to store page information
words_information = {}  # Dictionary to store word information
queries = []  # List to store user queries
relevant_documents = {}  # Dictionary to store relevant documents for queries

# Algorithm 1: Advanced Document Indexing Method
def process_document(document):
    # Extract page ID from the document's source code
    page_id_match = re.search(r'<id>(.*?)</id>', document)
    if page_id_match:
        page_id = int(page_id_match.group(1))
    else:
        page_id = 0  # Handle the case when no <id> tag is found

    # Extract page name from the document's source code
    page_name_match = re.search(r'<p-name>(.*?)</p-name>', document)
    if page_name_match:
        page_name = page_name_match.group(1)
    else:
        page_name = "Unknown Page"  # Handle the case when no <p-name> tag is found

    # Tokenize the content of the document
    content = re.sub(r'<.*?>', '', document)  # Remove HTML tags
    valid_tokens = re.findall(r'\b\w+\b', content)  # Tokenize based on word boundaries

    return page_id, page_name, valid_tokens

def advanced_document_indexing(dataset_path):
    # Initialize the data structures
    pages_information = {}
    words_information = {}

    # Replace this part with your logic to read and process documents
    # For demonstration, let's assume you have a list of documents
    documents = ["Document 1 content...", "Document 2 content...", "Document 3 content..."]

    for document in documents:
        # Process the document to extract page ID, page name, and valid tokens
        page_id, page_name, valid_tokens = process_document(document)

        # Update pages_information
        pages_information[page_id] = {
            'id': page_id,
            'p-name': page_name,
            'total-weight': 0,  # You can calculate the total weight here
            'total-count-word': len(valid_tokens)  # Total count of words
        }

        # Update words_information
        for token in valid_tokens:
            if token not in words_information:
                words_information[token] = {'pages-list': []}
            words_information[token]['pages-list'].append(page_id)

    # Now, you have updated pages_information and words_information
    return pages_information, words_information

# Usage example
dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"
pages_information, words_information = advanced_document_indexing(dataset_path)

# %%
# Algorithm 2: Query Search Algorithm (QSA)
def tokenize_query(query):
    # Replace with logic to tokenize the user query
    return query.split()

def retrieve_documents(query_tokens):
    # Replace with logic to retrieve documents based on query tokens
    return [random.randint(1, 1000) for _ in range(10)]

def query_search(query):
    query_tokens = tokenize_query(query)
    id_list = retrieve_documents(query_tokens)
    return id_list

# %%
# Algorithm 3: Genetic Algorithm (GA)
def initialize_population(population_size):
    # Replace with logic to initialize the population
    return [random.randint(0, 1) for _ in range(population_size)]

def evaluate_fitness(population, relevant_documents):
    # Replace with logic to evaluate the fitness of each chromosome
    return [random.random() for _ in range(len(population))]

def select_population(population, fitness_values):
    # Replace with logic to select individuals for the next generation
    return population[:len(population)//2]

def create_offspring(selected_population):
    # Replace with logic to create offspring through crossover and mutation
    return selected_population

def select_best_solution(population):
    # Replace with logic to select the best solution from the population
    return population[0]

def genetic_algorithm(population_size, num_iterations, relevant_documents):
    population = initialize_population(population_size)
    for iteration in range(num_iterations):
        fitness_values = evaluate_fitness(population, relevant_documents)
        selected_population = select_population(population, fitness_values)
        offspring_population = create_offspring(selected_population)
        population = offspring_population
    best_solution = select_best_solution(population)
    return best_solution

# %%
# Algorithm 4: Integration between MGA and CA
def split_dataset(dataset_path):
    # Replace with logic to split the dataset into training and testing sets
    training_set = []
    testing_set = []
    return training_set, testing_set

def evaluate_solution(solution, testing_set):
    # Replace with logic to evaluate the solution and calculate accuracy measures
    accuracy = random.uniform(0.7, 0.95)
    recall = random.uniform(0.6, 0.98)
    precision = random.uniform(0.65, 0.99)
    f1 = random.uniform(0.6, 0.97)
    return accuracy, recall, precision, f1

def save_result(result):
    # Replace with logic to save the best result
    # Example: Save the result to a file or database
    with open("results.txt", "a") as file:
        file.write(f"Accuracy: {result['accuracy']}\n")
        file.write(f"Recall: {result['recall']}\n")
        file.write(f"Precision: {result['precision']}\n")
        file.write(f"F1 Score: {result['f1']}\n")

def display_best_result():
    # Replace with logic to display the best result
    # Example: Print the best result to the console
    print("Best Result:")
    print(f"Accuracy: {best_result['accuracy']}")
    print(f"Recall: {best_result['recall']}")
    print(f"Precision: {best_result['precision']}")
    print(f"F1 Score: {best_result['f1']}")

# Main Function
if __name__ == "__main__":
    dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"
    num_iterations = 15
    threshold = 10
    accuracy_threshold = 0.9
    advanced_document_indexing(dataset_path)
    integration_algorithm(dataset_path, num_iterations, threshold, accuracy_threshold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4ee8c2ea4b27> in <cell line: 35>()
#      39     accuracy_threshold = 0.9
#      40     advanced_document_indexing(dataset_path)
# ---> 41     integration_algorithm(dataset_path, num_iterations, threshold, accuracy_threshold)
#
# NameError: name 'integration_algorithm' is not defined

# %%
import os
import re
import random
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import chardet

# Function to extract page ID from the filename
def get_page_id(file_name):
    match = re.search(r'page(\d+)', file_name)
    if match:
        return int(match.group(1))
    else:
        return None

# Function to extract page name from the filename
def get_page_name(file_name):
    # Extract page name from the filename by removing the file extension
    return os.path.splitext(file_name)[0]

# Function to preprocess text
def preprocess_text(text):
    # Tokenize the content by splitting on spaces (you can use more advanced tokenization)
    words = text.split()

    # Remove stop words, special characters, and sentence delimiters
    stop_words = set(["the", "and", "is", "in", "it", "an", "to", "of", "as", "by"])
    words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

    return words

# Function to preprocess HTML content
def preprocess_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract information from the document
    page_title_tag = soup.title
    if page_title_tag and page_title_tag.string:
        page_name = page_title_tag.string.strip()  # Extract page name
    else:
        page_name = "N/A"  # Assign a default value if no title tag or title text is found

    # Tokenize and preprocess the content
    text_content = soup.get_text()
    valid_tokens = preprocess_text(text_content)

    return page_name, text_content, valid_tokens

# Function to perform document indexing for both text and HTML
def document_indexing(dataset_path):
    pages_information = {}
    words_information = {}

    for root, dirs, files in os.walk(dataset_path):
        for file_name in files:
            file_path = os.path.join(root, file_name)  # Get the full file path

            # Detect the encoding of the file
            with open(file_path, 'rb') as file:
                raw_data = file.read()
                encoding_info = chardet.detect(raw_data)
                encoding = encoding_info['encoding']

            # Read the content using the detected encoding
            with open(file_path, 'r', encoding=encoding) as file:
                document_content = file.read()

            if file_path.endswith(".html"):  # Check the file path, not the file object
                # Process HTML content
                page_name, text_content, valid_tokens = preprocess_html(document_content)
            else:
                # Process text content
                page_name = get_page_name(file_name)
                valid_tokens = preprocess_text(document_content)

            # Store page information
            page_id = get_page_id(file_name)
            pages_information[page_id] = {
                "page_name": page_name,
                "total_weight": len(valid_tokens),
                "total_count_word": len(valid_tokens),
            }

            # Update words information
            for word in valid_tokens:
                if word not in words_information:
                    words_information[word] = {"pages_list": [page_id]}
                else:
                    words_information[word]["pages_list"].append(page_id)

    # Replace None with the actual count of occurrences
    for word, info in words_information.items():
        info["pages_list"] = len(info["pages_list"])

    return pages_information, words_information

# Function to perform query search
def query_search(user_query, words_information):
    query_words = preprocess_text(user_query)
    id_list = []

    for word in query_words:
        if word in words_information:
            id_list.extend([word] * words_information[word]["pages_list"])  # Count word occurrences
        else:
            print(f"Word '{word}' not found in indexed words.")

    return id_list

def calculate_accuracy(retrieved_ids, relevant_ids):
    tp = len(set(retrieved_ids).intersection(relevant_ids))
    fp = len(retrieved_ids) - tp
    fn = len(relevant_ids) - tp

    accuracy = (tp + 0.0) / (tp + fp + fn) if (tp + fp + fn) != 0 else 0.0
    precision = (tp + 0.0) / (tp + fp) if (tp + fp) != 0 else 0.0
    recall = (tp + 0.0) / (tp + fn) if (tp + fn) != 0 else 0.0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0.0

    return accuracy, precision, recall, f1

# Function to plot a bar chart for accuracy measures
def plot_accuracy_bar_chart(accuracy, precision, recall, f1):
    labels = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
    values = [accuracy, precision, recall, f1]  # No need to convert to float

    plt.bar(labels, values)
    plt.title('Accuracy Measures')
    plt.ylim(0, 1.2)
    plt.show()

    labels = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
    values = [accuracy, precision, recall, f1]

    plt.bar(labels, values)
    plt.title('Accuracy Measures')
    plt.ylim(0, 1.2)
    plt.show()

# Function to print semantic results
def print_semantic_results(pages_information, retrieved_ids, relevant_ids):
    print("ID\tQuery\tSemantic Results\tRecall\tPrecision")
    for page_id, page_info in pages_information.items():
        semantic_results = f"{retrieved_ids.count(page_id)} of {relevant_ids.count(page_id)}"

        # Calculate recall for the page
        recall = page_info.get('recall', 0.0)  # Get recall value from the 'pages_information' dictionary

        precision = "{:.2%}".format(page_info.get('precision', 0.0))

        print(f"{page_id}\t{page_info['page_name']}\t{semantic_results}\t{recall:.2%}\t{precision}")


# Example usage
if __name__ == "__main__":
    dataset_path = "/content/drive/MyDrive/Major_Project/Project_code/webkb-data/webkb"  # Replace with the path to your dataset

    # Algorithm 1: Document Indexing
    pages_information, words_information = document_indexing(dataset_path)

    # Algorithm 2: Query Search
    user_query = "information Retrieval"
    relevant_ids = [1, 0, 1]  # Example relevant IDs (modify with your actual relevant IDs)
    retrieved_ids = query_search(user_query, words_information)

    # Algorithm 3: Modified Genetic Algorithm
    population_size = 50
    num_iterations = 10
    best_solution = modified_genetic_algorithm(population_size, num_iterations, relevant_ids)


    # Algorithm 4: Calculate Accuracy Measures
    accuracy, precision, recall, f1 = calculate_accuracy(retrieved_ids, relevant_ids)

    # Print semantic results
    print_semantic_results(pages_information, retrieved_ids, relevant_ids)

    # Print results
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    # Plot accuracy measures
    plot_accuracy_bar_chart(accuracy, precision, recall, f1)
# Out:
# <ipython-input-12-8595e6ebe54a>:35: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, 'html.parser')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8595e6ebe54a> in <cell line: 156>()
#     168     population_size = 50
#     169     num_iterations = 10
# --> 170     best_solution = modified_genetic_algorithm(population_size, num_iterations, relevant_ids)
#     171
#     172
#
# TypeError: modified_genetic_algorithm() takes 2 positional arguments but 3 were given
